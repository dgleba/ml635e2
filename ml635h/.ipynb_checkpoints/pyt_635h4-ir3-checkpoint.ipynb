# %% [markdown]
# #
#
# Formula Trinity DUCSS - Object Detection
#
# how to make a traffic cone detector using [PyTorch](https://pytorch.org/).
#
# This notebook was adapted from the one in [Fine-tuning Faster-RCNN using pytorch](https://www.kaggle.com/yerramvarun/fine-tuning-faster-rcnn-using-pytorch/notebook)

# %% [markdown]
# ## Installs and Imports
#
# Install and import PyTorch along with a few helper libraries

# %% [markdown]
# Let's install some dependencies and clone the [TorchVision Repo](https://github.com/pytorch/vision) so we can use some helper files

# %%
# !pwd
# !ls
# Out:
# /notebooks/ml635e2/ml635h
# __pycache__    data.rar   img1	outmodel.pth	   pyt_635h4.ipynb  v-img
# coco_eval.py   engine.py  ir3	outmodelstate.pth  transforms.py    vision
# coco_utils.py  img	  more	pyt_635h3.ipynb    utils.py	    x

# %%
# !pwd
# Clone TorchVision repo and copy helper files
# !git clone https://github.com/pytorch/vision.git
# %cd vision
# !git checkout v0.3.0
# Out:
# /notebooks/ml635e2/635h
# Cloning into 'vision'...
# remote: Enumerating objects: 154831, done.
# remote: Counting objects: 100% (7204/7204), done.
# remote: Compressing objects: 100% (636/636), done.
# remote: Total 154831 (delta 6610), reused 7069 (delta 6538), pack-reused 147627
# Receiving objects: 100% (154831/154831), 306.64 MiB | 20.50 MiB/s, done.
# Resolving deltas: 100% (137189/137189), done.
# Updating files: 100% (816/816), done.
# /notebooks/ml635e2/635h/vision

# %%
# %%bash
# apt update
# DEBIAN_FRONTEND=noninteractive apt-get install -y python3-opencv
# #tz prompt. dpkg fix...
# pip install opencv-python
# #pip install cv2
# Out:
# Get:1 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:2 http://ppa.launchpad.net/git-core/ppa/ubuntu bionic InRelease [20.8 kB]
# Hit:3 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:4 http://security.ubuntu.com/ubuntu bionic-security/multiverse amd64 Packages [22.8 kB]
# Get:5 http://security.ubuntu.com/ubuntu bionic-security/restricted amd64 Packages [982 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:7 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [1515 kB]
# Get:8 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [2830 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Get:10 http://ppa.launchpad.net/git-core/ppa/ubuntu bionic/main amd64 Packages [3163 B]
# Get:11 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [2290 kB]
# Get:12 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [3262 kB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic-updates/multiverse amd64 Packages [29.8 kB]
# Get:14 http://archive.ubuntu.com/ubuntu bionic-updates/restricted amd64 Packages [1015 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic-backports/universe amd64 Packages [12.9 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic-backports/main amd64 Packages [12.2 kB]
# Fetched 12.2 MB in 2s (7899 kB/s)
# Reading package lists...
# Building dependency tree...
# Reading state information...
# 76 packages can be upgraded. Run 'apt list --upgradable' to see them.
# Reading package lists...
# Building dependency tree...
# Reading state information...
# The following additional packages will be installed:
#   adwaita-icon-theme at-spi2-core dconf-gsettings-backend dconf-service
#   gdal-data glib-networking glib-networking-common glib-networking-services
#   gsettings-desktop-schemas gtk-update-icon-cache hicolor-icon-theme
#   humanity-icon-theme i965-va-driver ibverbs-providers libaacs0 libaec0
#   libarmadillo8 libarpack2 libatk-bridge2.0-0 libatk1.0-0 libatk1.0-data
#   libatspi2.0-0 libavahi-client3 libavahi-common-data libavahi-common3
#   libavcodec57 libavformat57 libavutil55 libbdplus0 libblas3 libbluray2
#   libcairo-gobject2 libcharls1 libchromaprint1 libcolord2 libcroco3
#   libcrystalhd3 libcups2 libdap25 libdapclient6v5 libdc1394-22 libdconf1
#   libdrm-amdgpu1 libdrm-common libdrm-intel1 libdrm-nouveau2 libdrm-radeon1
#   libdrm2 libepoxy0 libepsilon1 libexif12 libfabric1 libfreexl1 libfyba0
#   libgdal20 libgdcm2.8 libgdk-pixbuf2.0-0 libgdk-pixbuf2.0-bin
#   libgdk-pixbuf2.0-common libgeos-3.6.2 libgeos-c1v5 libgeotiff2 libgfortran4
#   libgif7 libgl1 libgl1-mesa-dri libgl1-mesa-glx libgl2ps1.4 libglapi-mesa
#   libglvnd0 libglx-mesa0 libglx0 libgme0 libgphoto2-6 libgphoto2-l10n
#   libgphoto2-port12 libgsm1 libgtk-3-0 libgtk-3-bin libgtk-3-common
#   libhdf4-0-alt libhdf5-100 libhdf5-openmpi-100 libhwloc-plugins libhwloc5
#   libibverbs1 libilmbase12 libjson-c3 libjson-glib-1.0-0
#   libjson-glib-1.0-common libjsoncpp1 libkmlbase1 libkmldom1 libkmlengine1
#   liblapack3 liblcms2-2 liblept5 libllvm10 libminizip1 libmp3lame0 libmpg123-0
#   libmysqlclient20 libnetcdf-c++4 libnetcdf13 libnl-3-200 libnl-route-3-200
#   libnspr4 libnss3 libnuma1 libodbc1 libogdi3.2 libogg0 libopencv-calib3d3.2
#   libopencv-contrib3.2 libopencv-core3.2 libopencv-features2d3.2
#   libopencv-flann3.2 libopencv-highgui3.2 libopencv-imgcodecs3.2
#   libopencv-imgproc3.2 libopencv-ml3.2 libopencv-objdetect3.2
#   libopencv-photo3.2 libopencv-shape3.2 libopencv-stitching3.2
#   libopencv-superres3.2 libopencv-video3.2 libopencv-videoio3.2
#   libopencv-videostab3.2 libopencv-viz3.2 libopenexr22 libopenjp2-7
#   libopenmpi2 libopenmpt0 libopus0 libpciaccess0 libpoppler73 libpq5 libproj12
#   libproxy1v5 libpsm-infinipath1 libpython2.7 libpython2.7-minimal
#   libpython2.7-stdlib libqhull7 libraw1394-11 librdmacm1 librest-0.7-0
#   librsvg2-2 librsvg2-common libsensors4 libshine3 libsnappy1v5 libsocket++1
#   libsoup-gnome2.4-1 libsoup2.4-1 libsoxr0 libspatialite7 libspeex1
#   libssh-gcrypt-4 libsuperlu5 libswresample2 libswscale4 libsz2 libtbb2
#   libtcl8.6 libtesseract4 libtheora0 libtk8.6 libtwolame0 liburiparser1
#   libusb-1.0-0 libva-drm2 libva-x11-2 libva2 libvdpau1 libvorbis0a
#   libvorbisenc2 libvorbisfile3 libvpx5 libvtk6.3 libwavpack1
#   libwayland-client0 libwayland-cursor0 libwayland-egl1 libwebpmux3
#   libx11-xcb1 libx264-152 libx265-146 libxcb-dri2-0 libxcb-dri3-0 libxcb-glx0
#   libxcb-present0 libxcb-sync1 libxcb-xfixes0 libxcomposite1 libxcursor1
#   libxdamage1 libxerces-c3.2 libxfixes3 libxft2 libxi6 libxinerama1
#   libxkbcommon0 libxrandr2 libxshmfence1 libxss1 libxtst6 libxvidcore4
#   libxxf86vm1 libzvbi-common libzvbi0 mesa-va-drivers mesa-vdpau-drivers
#   mysql-common ocl-icd-libopencl1 odbcinst odbcinst1debian2 openmpi-bin
#   openmpi-common poppler-data proj-bin proj-data python3-numpy tzdata
#   ubuntu-mono va-driver-all vdpau-driver-all xkb-data
# Suggested packages:
#   i965-va-driver-shaders libbluray-bdj colord firmware-crystalhd cups-common
#   geotiff-bin gdal-bin libgeotiff-epsg gphoto2 gvfs libhdf4-doc
#   libhdf4-alt-dev hdf4-tools libhwloc-contrib-plugins liblcms2-utils libmyodbc
#   odbc-postgresql tdsodbc unixodbc-bin ogdi-bin opus-tools pciutils
#   libraw1394-doc librsvg2-bin lm-sensors speex tcl8.6 tk8.6 mpi-default-bin
#   vtk6-doc vtk6-examples opencl-icd gfortran poppler-utils ghostscript
#   fonts-japanese-mincho | fonts-ipafont-mincho fonts-japanese-gothic
#   | fonts-ipafont-gothic fonts-arphic-ukai fonts-arphic-uming fonts-nanum
#   python-numpy-doc python3-dev python3-nose python3-numpy-dbg libvdpau-va-gl1
#   nvidia-vdpau-driver nvidia-legacy-340xx-vdpau-driver
# The following NEW packages will be installed:
#   adwaita-icon-theme at-spi2-core dconf-gsettings-backend dconf-service
#   gdal-data glib-networking glib-networking-common glib-networking-services
#   gsettings-desktop-schemas gtk-update-icon-cache hicolor-icon-theme
#   humanity-icon-theme i965-va-driver ibverbs-providers libaacs0 libaec0
#   libarmadillo8 libarpack2 libatk-bridge2.0-0 libatk1.0-0 libatk1.0-data
#   libatspi2.0-0 libavahi-client3 libavahi-common-data libavahi-common3
#   libavcodec57 libavformat57 libavutil55 libbdplus0 libblas3 libbluray2
#   libcairo-gobject2 libcharls1 libchromaprint1 libcolord2 libcroco3
#   libcrystalhd3 libcups2 libdap25 libdapclient6v5 libdc1394-22 libdconf1
#   libdrm-amdgpu1 libdrm-common libdrm-intel1 libdrm-nouveau2 libdrm-radeon1
#   libdrm2 libepoxy0 libepsilon1 libexif12 libfabric1 libfreexl1 libfyba0
#   libgdal20 libgdcm2.8 libgdk-pixbuf2.0-0 libgdk-pixbuf2.0-bin
#   libgdk-pixbuf2.0-common libgeos-3.6.2 libgeos-c1v5 libgeotiff2 libgfortran4
#   libgif7 libgl1 libgl1-mesa-dri libgl1-mesa-glx libgl2ps1.4 libglapi-mesa
#   libglvnd0 libglx-mesa0 libglx0 libgme0 libgphoto2-6 libgphoto2-l10n
#   libgphoto2-port12 libgsm1 libgtk-3-0 libgtk-3-bin libgtk-3-common
#   libhdf4-0-alt libhdf5-100 libhdf5-openmpi-100 libhwloc-plugins libhwloc5
#   libibverbs1 libilmbase12 libjson-c3 libjson-glib-1.0-0
#   libjson-glib-1.0-common libjsoncpp1 libkmlbase1 libkmldom1 libkmlengine1
#   liblapack3 liblcms2-2 liblept5 libllvm10 libminizip1 libmp3lame0 libmpg123-0
#   libmysqlclient20 libnetcdf-c++4 libnetcdf13 libnl-3-200 libnl-route-3-200
#   libnspr4 libnss3 libnuma1 libodbc1 libogdi3.2 libogg0 libopencv-calib3d3.2
#   libopencv-contrib3.2 libopencv-core3.2 libopencv-features2d3.2
#   libopencv-flann3.2 libopencv-highgui3.2 libopencv-imgcodecs3.2
#   libopencv-imgproc3.2 libopencv-ml3.2 libopencv-objdetect3.2
#   libopencv-photo3.2 libopencv-shape3.2 libopencv-stitching3.2
#   libopencv-superres3.2 libopencv-video3.2 libopencv-videoio3.2
#   libopencv-videostab3.2 libopencv-viz3.2 libopenexr22 libopenjp2-7
#   libopenmpi2 libopenmpt0 libopus0 libpciaccess0 libpoppler73 libpq5 libproj12
#   libproxy1v5 libpsm-infinipath1 libpython2.7 libpython2.7-minimal
#   libpython2.7-stdlib libqhull7 libraw1394-11 librdmacm1 librest-0.7-0
#   librsvg2-2 librsvg2-common libsensors4 libshine3 libsnappy1v5 libsocket++1
#   libsoup-gnome2.4-1 libsoup2.4-1 libsoxr0 libspatialite7 libspeex1
#   libssh-gcrypt-4 libsuperlu5 libswresample2 libswscale4 libsz2 libtbb2
#   libtcl8.6 libtesseract4 libtheora0 libtk8.6 libtwolame0 liburiparser1
#   libusb-1.0-0 libva-drm2 libva-x11-2 libva2 libvdpau1 libvorbis0a
#   libvorbisenc2 libvorbisfile3 libvpx5 libvtk6.3 libwavpack1
#   libwayland-client0 libwayland-cursor0 libwayland-egl1 libwebpmux3
#   libx11-xcb1 libx264-152 libx265-146 libxcb-dri2-0 libxcb-dri3-0 libxcb-glx0
#   libxcb-present0 libxcb-sync1 libxcb-xfixes0 libxcomposite1 libxcursor1
#   libxdamage1 libxerces-c3.2 libxfixes3 libxft2 libxi6 libxinerama1
#   libxkbcommon0 libxrandr2 libxshmfence1 libxss1 libxtst6 libxvidcore4
#   libxxf86vm1 libzvbi-common libzvbi0 mesa-va-drivers mesa-vdpau-drivers
#   mysql-common ocl-icd-libopencl1 odbcinst odbcinst1debian2 openmpi-bin
#   openmpi-common poppler-data proj-bin proj-data python3-numpy python3-opencv
#   tzdata ubuntu-mono va-driver-all vdpau-driver-all xkb-data
# 0 upgraded, 230 newly installed, 0 to remove and 76 not upgraded.
# Need to get 131 MB of archives.
# After this operation, 846 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 libogg0 amd64 1.3.2-1 [17.2 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxft2 amd64 2.3.2-1 [36.1 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxinerama1 amd64 2:1.1.3-1 [7908 B]
# Get:4 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxss1 amd64 1:1.2.2-1 [8582 B]
# Get:5 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxxf86vm1 amd64 1:1.1.4-1 [10.6 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic/main amd64 poppler-data all 0.4.8-2 [1479 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libjson-c3 amd64 0.12.1-1.3ubuntu0.3 [21.7 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 tzdata all 2022a-0ubuntu0.18.04 [190 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 xkb-data all 2.23.1-1ubuntu1.18.04.1 [325 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libdrm-common all 2.4.101-2~18.04.1 [5560 B]
# Get:11 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libdrm2 amd64 2.4.101-2~18.04.1 [32.3 kB]
# Get:12 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libnuma1 amd64 2.0.11-2.1ubuntu0.1 [22.0 kB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic/main amd64 libusb-1.0-0 amd64 2:1.0.21-2 [43.3 kB]
# Get:14 http://archive.ubuntu.com/ubuntu bionic/main amd64 hicolor-icon-theme all 0.17-2 [9976 B]
# Get:15 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgdk-pixbuf2.0-common all 2.36.11-2 [4536 B]
# Get:16 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgdk-pixbuf2.0-0 amd64 2.36.11-2 [165 kB]
# Get:17 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gtk-update-icon-cache amd64 3.22.30-1ubuntu4 [28.3 kB]
# Get:18 http://archive.ubuntu.com/ubuntu bionic/main amd64 libcroco3 amd64 0.6.12-2 [81.3 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 librsvg2-2 amd64 2.40.20-2ubuntu0.2 [98.6 kB]
# Get:20 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 librsvg2-common amd64 2.40.20-2ubuntu0.2 [5064 B]
# Get:21 http://archive.ubuntu.com/ubuntu bionic/main amd64 humanity-icon-theme all 0.6.15 [1250 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 ubuntu-mono all 16.10+18.04.20181005-0ubuntu1 [149 kB]
# Get:23 http://archive.ubuntu.com/ubuntu bionic/main amd64 adwaita-icon-theme all 3.28.0-1ubuntu1 [3306 kB]
# Get:24 http://archive.ubuntu.com/ubuntu bionic/main amd64 libatspi2.0-0 amd64 2.28.0-1 [59.6 kB]
# Get:25 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxtst6 amd64 2:1.2.3-1 [12.8 kB]
# Get:26 http://archive.ubuntu.com/ubuntu bionic/main amd64 at-spi2-core amd64 2.28.0-1 [47.9 kB]
# Get:27 http://archive.ubuntu.com/ubuntu bionic/main amd64 libdconf1 amd64 0.26.0-2ubuntu3 [33.1 kB]
# Get:28 http://archive.ubuntu.com/ubuntu bionic/main amd64 dconf-service amd64 0.26.0-2ubuntu3 [28.4 kB]
# Get:29 http://archive.ubuntu.com/ubuntu bionic/main amd64 dconf-gsettings-backend amd64 0.26.0-2ubuntu3 [20.0 kB]
# Get:30 http://archive.ubuntu.com/ubuntu bionic/universe amd64 gdal-data all 2.2.3+dfsg-2 [363 kB]
# Get:31 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libproxy1v5 amd64 0.4.15-1ubuntu0.2 [48.7 kB]
# Get:32 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 glib-networking-common all 2.56.0-1ubuntu0.1 [3476 B]
# Get:33 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 glib-networking-services amd64 2.56.0-1ubuntu0.1 [8632 B]
# Get:34 http://archive.ubuntu.com/ubuntu bionic/main amd64 gsettings-desktop-schemas all 3.28.0-1ubuntu1 [27.8 kB]
# Get:35 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 glib-networking amd64 2.56.0-1ubuntu0.1 [56.7 kB]
# Get:36 http://archive.ubuntu.com/ubuntu bionic/main amd64 libnl-3-200 amd64 3.2.29-0ubuntu3 [52.8 kB]
# Get:37 http://archive.ubuntu.com/ubuntu bionic/main amd64 libnl-route-3-200 amd64 3.2.29-0ubuntu3 [146 kB]
# Get:38 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libibverbs1 amd64 17.1-1ubuntu0.2 [44.4 kB]
# Get:39 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 ibverbs-providers amd64 17.1-1ubuntu0.2 [160 kB]
# Get:40 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libaacs0 amd64 0.9.0-1 [51.4 kB]
# Get:41 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libaec0 amd64 0.3.2-2 [18.1 kB]
# Get:42 http://archive.ubuntu.com/ubuntu bionic/main amd64 libblas3 amd64 3.7.1-4ubuntu1 [140 kB]
# Get:43 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgfortran4 amd64 7.5.0-3ubuntu1~18.04 [492 kB]
# Get:44 http://archive.ubuntu.com/ubuntu bionic/main amd64 liblapack3 amd64 3.7.1-4ubuntu1 [2112 kB]
# Get:45 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libarpack2 amd64 3.5.0+real-2 [89.7 kB]
# Get:46 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libsuperlu5 amd64 5.2.1+dfsg1-3 [161 kB]
# Get:47 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libarmadillo8 amd64 1:8.400.0+dfsg-2 [81.9 kB]
# Get:48 http://archive.ubuntu.com/ubuntu bionic/main amd64 libatk1.0-data all 2.28.1-1 [2992 B]
# Get:49 http://archive.ubuntu.com/ubuntu bionic/main amd64 libatk1.0-0 amd64 2.28.1-1 [43.9 kB]
# Get:50 http://archive.ubuntu.com/ubuntu bionic/main amd64 libatk-bridge2.0-0 amd64 2.26.2-1 [57.3 kB]
# Get:51 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libavahi-common-data amd64 0.7-3.1ubuntu1.3 [22.2 kB]
# Get:52 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libavahi-common3 amd64 0.7-3.1ubuntu1.3 [21.6 kB]
# Get:53 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libavahi-client3 amd64 0.7-3.1ubuntu1.3 [25.2 kB]
# Get:54 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libva2 amd64 2.1.0-3 [47.6 kB]
# Get:55 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libva-drm2 amd64 2.1.0-3 [6880 B]
# Get:56 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxfixes3 amd64 1:5.0.3-1 [10.8 kB]
# Get:57 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libva-x11-2 amd64 2.1.0-3 [11.5 kB]
# Get:58 http://archive.ubuntu.com/ubuntu bionic/main amd64 libvdpau1 amd64 1.1.1-3ubuntu1 [25.5 kB]
# Get:59 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libavutil55 amd64 7:3.4.11-0ubuntu0.1 [191 kB]
# Get:60 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libcrystalhd3 amd64 1:0.0~git20110715.fdd2f19-12 [45.8 kB]
# Get:61 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libgsm1 amd64 1.0.13-4build1 [22.4 kB]
# Get:62 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmp3lame0 amd64 3.100-2 [136 kB]
# Get:63 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libopenjp2-7 amd64 2.3.0-2build0.18.04.1 [145 kB]
# Get:64 http://archive.ubuntu.com/ubuntu bionic/main amd64 libopus0 amd64 1.1.2-1ubuntu1 [159 kB]
# Get:65 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libshine3 amd64 3.1.1-1 [22.9 kB]
# Get:66 http://archive.ubuntu.com/ubuntu bionic/main amd64 libsnappy1v5 amd64 1.1.7-1 [16.0 kB]
# Get:67 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libspeex1 amd64 1.2~rc1.2-1ubuntu2.1 [52.1 kB]
# Get:68 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libsoxr0 amd64 0.1.2-3 [65.9 kB]
# Get:69 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libswresample2 amd64 7:3.4.11-0ubuntu0.1 [55.2 kB]
# Get:70 http://archive.ubuntu.com/ubuntu bionic/main amd64 libtheora0 amd64 1.1.1+dfsg.1-14 [170 kB]
# Get:71 http://archive.ubuntu.com/ubuntu bionic/main amd64 libtwolame0 amd64 0.3.13-3 [46.7 kB]
# Get:72 http://archive.ubuntu.com/ubuntu bionic/main amd64 libvorbis0a amd64 1.3.5-4.2 [86.4 kB]
# Get:73 http://archive.ubuntu.com/ubuntu bionic/main amd64 libvorbisenc2 amd64 1.3.5-4.2 [70.7 kB]
# Get:74 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libvpx5 amd64 1.7.0-3ubuntu0.18.04.1 [796 kB]
# Get:75 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libwavpack1 amd64 5.1.0-2ubuntu1.5 [76.8 kB]
# Get:76 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libwebpmux3 amd64 0.6.1-2ubuntu0.18.04.1 [19.6 kB]
# Get:77 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libx264-152 amd64 2:0.152.2854+gite9a5903-2 [609 kB]
# Get:78 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libx265-146 amd64 2.6-3 [1026 kB]
# Get:79 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libxvidcore4 amd64 2:1.3.5-1 [200 kB]
# Get:80 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libzvbi-common all 0.2.35-13 [32.1 kB]
# Get:81 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libzvbi0 amd64 0.2.35-13 [235 kB]
# Get:82 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libavcodec57 amd64 7:3.4.11-0ubuntu0.1 [4600 kB]
# Get:83 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libbluray2 amd64 1:1.0.2-3 [141 kB]
# Get:84 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libchromaprint1 amd64 1.4.3-1 [36.8 kB]
# Get:85 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libgme0 amd64 0.6.2-1 [121 kB]
# Get:86 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmpg123-0 amd64 1.25.10-1 [125 kB]
# Get:87 http://archive.ubuntu.com/ubuntu bionic/main amd64 libvorbisfile3 amd64 1.3.5-4.2 [16.0 kB]
# Get:88 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libopenmpt0 amd64 0.3.6-1 [561 kB]
# Get:89 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libssh-gcrypt-4 amd64 0.8.0~20170825.94fa1e38-1ubuntu0.7 [172 kB]
# Get:90 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libavformat57 amd64 7:3.4.11-0ubuntu0.1 [953 kB]
# Get:91 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libbdplus0 amd64 0.1.2-2 [46.6 kB]
# Get:92 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libcairo-gobject2 amd64 1.15.10-2ubuntu0.1 [17.1 kB]
# Get:93 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libcharls1 amd64 1.1.0+dfsg-2 [56.1 kB]
# Get:94 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 liblcms2-2 amd64 2.9-1ubuntu0.1 [139 kB]
# Get:95 http://archive.ubuntu.com/ubuntu bionic/main amd64 libcolord2 amd64 1.3.3-2build1 [107 kB]
# Get:96 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libcups2 amd64 2.2.7-1ubuntu2.9 [211 kB]
# Get:97 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libdap25 amd64 3.19.1-2build1 [426 kB]
# Get:98 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libdapclient6v5 amd64 3.19.1-2build1 [88.9 kB]
# Get:99 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libdrm-amdgpu1 amd64 2.4.101-2~18.04.1 [18.2 kB]
# Get:100 http://archive.ubuntu.com/ubuntu bionic/main amd64 libpciaccess0 amd64 0.14-1 [17.9 kB]
# Get:101 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libdrm-intel1 amd64 2.4.101-2~18.04.1 [60.0 kB]
# Get:102 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libdrm-nouveau2 amd64 2.4.101-2~18.04.1 [16.5 kB]
# Get:103 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libdrm-radeon1 amd64 2.4.101-2~18.04.1 [21.7 kB]
# Get:104 http://archive.ubuntu.com/ubuntu bionic/main amd64 libepoxy0 amd64 1.4.3-1 [181 kB]
# Get:105 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libepsilon1 amd64 0.9.2+dfsg-2 [41.2 kB]
# Get:106 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libexif12 amd64 0.6.21-4ubuntu0.6 [78.7 kB]
# Get:107 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libpsm-infinipath1 amd64 3.3+20.604758e7-5 [174 kB]
# Get:108 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 librdmacm1 amd64 17.1-1ubuntu0.2 [56.1 kB]
# Get:109 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libfabric1 amd64 1.5.3-1 [302 kB]
# Get:110 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libfyba0 amd64 4.1.1-3 [110 kB]
# Get:111 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libfreexl1 amd64 1.0.5-1 [33.4 kB]
# Get:112 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libgeos-3.6.2 amd64 3.6.2-1build2 [476 kB]
# Get:113 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libgeos-c1v5 amd64 3.6.2-1build2 [54.9 kB]
# Get:114 http://archive.ubuntu.com/ubuntu bionic/universe amd64 proj-data all 4.9.3-2 [4020 kB]
# Get:115 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libproj12 amd64 4.9.3-2 [159 kB]
# Get:116 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libgeotiff2 amd64 1.4.2-2build1 [58.5 kB]
# Get:117 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgif7 amd64 5.1.4-2ubuntu0.1 [30.9 kB]
# Get:118 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libhdf4-0-alt amd64 4.2.13-2 [267 kB]
# Get:119 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libsz2 amd64 0.3.2-2 [5114 B]
# Get:120 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libhdf5-100 amd64 1.10.0-patch1+docs-4 [1256 kB]
# Get:121 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libminizip1 amd64 1.1-8build1 [20.2 kB]
# Get:122 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 liburiparser1 amd64 0.8.4-1+deb9u2build0.18.04.1 [38.7 kB]
# Get:123 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libkmlbase1 amd64 1.3.0-5 [44.9 kB]
# Get:124 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libkmldom1 amd64 1.3.0-5 [165 kB]
# Get:125 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libkmlengine1 amd64 1.3.0-5 [73.7 kB]
# Get:126 http://archive.ubuntu.com/ubuntu bionic/main amd64 mysql-common all 5.8+1.0.4 [7308 B]
# Get:127 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmysqlclient20 amd64 5.7.38-0ubuntu0.18.04.1 [689 kB]
# Get:128 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libnetcdf13 amd64 1:4.6.0-2build1 [333 kB]
# Get:129 http://archive.ubuntu.com/ubuntu bionic/main amd64 libodbc1 amd64 2.3.4-1.1ubuntu3 [183 kB]
# Get:130 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libogdi3.2 amd64 3.2.0+ds-2 [213 kB]
# Get:131 http://archive.ubuntu.com/ubuntu bionic/main amd64 libnspr4 amd64 2:4.18-1ubuntu1 [112 kB]
# Get:132 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libnss3 amd64 2:3.35-2ubuntu2.14 [1220 kB]
# Get:133 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpoppler73 amd64 0.62.0-2ubuntu2.12 [800 kB]
# Get:134 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpq5 amd64 10.21-0ubuntu0.18.04.1 [108 kB]
# Get:135 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libqhull7 amd64 2015.2-4 [152 kB]
# Get:136 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libspatialite7 amd64 4.3.0a-5build1 [1224 kB]
# Get:137 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libxerces-c3.2 amd64 3.2.0+debian-2 [851 kB]
# Get:138 http://archive.ubuntu.com/ubuntu bionic/main amd64 odbcinst amd64 2.3.4-1.1ubuntu3 [12.4 kB]
# Get:139 http://archive.ubuntu.com/ubuntu bionic/main amd64 odbcinst1debian2 amd64 2.3.4-1.1ubuntu3 [40.4 kB]
# Get:140 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libgdal20 amd64 2.2.3+dfsg-2 [5099 kB]
# Get:141 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libsocket++1 amd64 1.12.13-9 [38.0 kB]
# Get:142 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libgdcm2.8 amd64 2.8.4-1build2 [1834 kB]
# Get:143 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgdk-pixbuf2.0-bin amd64 2.36.11-2 [7864 B]
# Get:144 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libglapi-mesa amd64 20.0.8-0ubuntu1~18.04.1 [26.6 kB]
# Get:145 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libllvm10 amd64 1:10.0.0-4ubuntu1~18.04.2 [15.4 MB]
# Get:146 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libsensors4 amd64 1:3.4.0-4ubuntu0.1 [28.3 kB]
# Get:147 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgl1-mesa-dri amd64 20.0.8-0ubuntu1~18.04.1 [9333 kB]
# Get:148 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libglvnd0 amd64 1.0.0-2ubuntu2.3 [47.0 kB]
# Get:149 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libx11-xcb1 amd64 2:1.6.4-3ubuntu0.4 [9720 B]
# Get:150 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libxcb-dri2-0 amd64 1.13-2~ubuntu18.04 [6920 B]
# Get:151 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libxcb-dri3-0 amd64 1.13-2~ubuntu18.04 [6568 B]
# Get:152 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libxcb-glx0 amd64 1.13-2~ubuntu18.04 [22.1 kB]
# Get:153 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libxcb-present0 amd64 1.13-2~ubuntu18.04 [5552 B]
# Get:154 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libxcb-sync1 amd64 1.13-2~ubuntu18.04 [8808 B]
# Get:155 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxdamage1 amd64 1:1.1.4-3 [6934 B]
# Get:156 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxshmfence1 amd64 1.3-1 [5028 B]
# Get:157 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libglx-mesa0 amd64 20.0.8-0ubuntu1~18.04.1 [139 kB]
# Get:158 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libglx0 amd64 1.0.0-2ubuntu2.3 [28.1 kB]
# Get:159 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgl1 amd64 1.0.0-2ubuntu2.3 [86.2 kB]
# Get:160 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgl1-mesa-glx amd64 20.0.8-0ubuntu1~18.04.1 [5532 B]
# Get:161 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libgl2ps1.4 amd64 1.4.0+dfsg1-1 [37.9 kB]
# Get:162 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgphoto2-port12 amd64 2.5.16-2 [50.2 kB]
# Get:163 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgphoto2-6 amd64 2.5.16-2 [830 kB]
# Get:164 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgphoto2-l10n all 2.5.16-2 [11.1 kB]
# Get:165 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgtk-3-common all 3.22.30-1ubuntu4 [229 kB]
# Get:166 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libjson-glib-1.0-common all 1.4.2-3ubuntu0.18.04.1 [3480 B]
# Get:167 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libjson-glib-1.0-0 amd64 1.4.2-3ubuntu0.18.04.1 [58.4 kB]
# Get:168 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libsoup2.4-1 amd64 2.62.1-1ubuntu0.4 [292 kB]
# Get:169 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libsoup-gnome2.4-1 amd64 2.62.1-1ubuntu0.4 [5088 B]
# Get:170 http://archive.ubuntu.com/ubuntu bionic/main amd64 librest-0.7-0 amd64 0.8.0-2 [31.8 kB]
# Get:171 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libwayland-client0 amd64 1.16.0-1ubuntu1.1~18.04.3 [23.6 kB]
# Get:172 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libwayland-cursor0 amd64 1.16.0-1ubuntu1.1~18.04.3 [10.1 kB]
# Get:173 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libwayland-egl1 amd64 1.16.0-1ubuntu1.1~18.04.3 [5464 B]
# Get:174 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxcomposite1 amd64 1:0.4.4-2 [6988 B]
# Get:175 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxcursor1 amd64 1:1.1.15-1 [19.8 kB]
# Get:176 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxi6 amd64 2:1.7.9-1 [29.2 kB]
# Get:177 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libxkbcommon0 amd64 0.8.2-1~ubuntu18.04.1 [97.8 kB]
# Get:178 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxrandr2 amd64 2:1.5.1-1 [18.1 kB]
# Get:179 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgtk-3-0 amd64 3.22.30-1ubuntu4 [2503 kB]
# Get:180 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgtk-3-bin amd64 3.22.30-1ubuntu4 [57.4 kB]
# Get:181 http://archive.ubuntu.com/ubuntu bionic/main amd64 libilmbase12 amd64 2.2.0-11ubuntu2 [71.4 kB]
# Get:182 http://archive.ubuntu.com/ubuntu bionic/universe amd64 liblept5 amd64 1.75.3-3 [929 kB]
# Get:183 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libnetcdf-c++4 amd64 4.2-8 [33.3 kB]
# Get:184 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libtbb2 amd64 2017~U7-8 [110 kB]
# Get:185 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libopencv-core3.2 amd64 3.2.0+dfsg-4ubuntu0.1 [709 kB]
# Get:186 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libopencv-flann3.2 amd64 3.2.0+dfsg-4ubuntu0.1 [91.5 kB]
# Get:187 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libopencv-imgproc3.2 amd64 3.2.0+dfsg-4ubuntu0.1 [818 kB]
# Get:188 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libopenexr22 amd64 2.2.0-11.1ubuntu1.9 [559 kB]
# Get:189 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libopencv-imgcodecs3.2 amd64 3.2.0+dfsg-4ubuntu0.1 [82.3 kB]
# Get:190 http://archive.ubuntu.com/ubuntu bionic/main amd64 libraw1394-11 amd64 2.1.2-1 [30.7 kB]
# Get:191 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libdc1394-22 amd64 2.2.5-1 [77.5 kB]
# Get:192 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libswscale4 amd64 7:3.4.11-0ubuntu0.1 [150 kB]
# Get:193 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libopencv-videoio3.2 amd64 3.2.0+dfsg-4ubuntu0.1 [77.2 kB]
# Get:194 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libopencv-highgui3.2 amd64 3.2.0+dfsg-4ubuntu0.1 [18.9 kB]
# Get:195 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libopencv-ml3.2 amd64 3.2.0+dfsg-4ubuntu0.1 [223 kB]
# Get:196 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libopencv-features2d3.2 amd64 3.2.0+dfsg-4ubuntu0.1 [231 kB]
# Get:197 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libopencv-calib3d3.2 amd64 3.2.0+dfsg-4ubuntu0.1 [427 kB]
# Get:198 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libopencv-objdetect3.2 amd64 3.2.0+dfsg-4ubuntu0.1 [137 kB]
# Get:199 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libopencv-photo3.2 amd64 3.2.0+dfsg-4ubuntu0.1 [188 kB]
# Get:200 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libopencv-video3.2 amd64 3.2.0+dfsg-4ubuntu0.1 [122 kB]
# Get:201 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libopencv-shape3.2 amd64 3.2.0+dfsg-4ubuntu0.1 [56.3 kB]
# Get:202 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libopencv-stitching3.2 amd64 3.2.0+dfsg-4ubuntu0.1 [166 kB]
# Get:203 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libopencv-superres3.2 amd64 3.2.0+dfsg-4ubuntu0.1 [42.4 kB]
# Get:204 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libopencv-videostab3.2 amd64 3.2.0+dfsg-4ubuntu0.1 [97.7 kB]
# Get:205 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libhwloc5 amd64 1.11.9-1 [105 kB]
# Get:206 http://archive.ubuntu.com/ubuntu bionic/main amd64 ocl-icd-libopencl1 amd64 2.2.11-1ubuntu1 [30.3 kB]
# Get:207 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libhwloc-plugins amd64 1.11.9-1 [12.5 kB]
# Get:208 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libopenmpi2 amd64 2.1.1-8 [2056 kB]
# Get:209 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libhdf5-openmpi-100 amd64 1.10.0-patch1+docs-4 [1289 kB]
# Get:210 http://archive.ubuntu.com/ubuntu bionic/main amd64 libjsoncpp1 amd64 1.7.4-3 [73.6 kB]
# Get:211 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpython2.7-minimal amd64 2.7.17-1~18.04ubuntu1.7 [335 kB]
# Get:212 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpython2.7-stdlib amd64 2.7.17-1~18.04ubuntu1.7 [1917 kB]
# Get:213 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpython2.7 amd64 2.7.17-1~18.04ubuntu1.7 [1054 kB]
# Get:214 http://archive.ubuntu.com/ubuntu bionic/main amd64 libtcl8.6 amd64 8.6.8+dfsg-3 [881 kB]
# Get:215 http://archive.ubuntu.com/ubuntu bionic/main amd64 libtk8.6 amd64 8.6.8-4 [693 kB]
# Get:216 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libvtk6.3 amd64 6.3.0+dfsg1-11build1 [31.5 MB]
# Get:217 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libopencv-viz3.2 amd64 3.2.0+dfsg-4ubuntu0.1 [111 kB]
# Get:218 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libtesseract4 amd64 4.00~git2288-10f4998a-2 [1163 kB]
# Get:219 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libopencv-contrib3.2 amd64 3.2.0+dfsg-4ubuntu0.1 [1450 kB]
# Get:220 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libxcb-xfixes0 amd64 1.13-2~ubuntu18.04 [9352 B]
# Get:221 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 mesa-va-drivers amd64 20.0.8-0ubuntu1~18.04.1 [2376 kB]
# Get:222 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 mesa-vdpau-drivers amd64 20.0.8-0ubuntu1~18.04.1 [2496 kB]
# Get:223 http://archive.ubuntu.com/ubuntu bionic/universe amd64 openmpi-common all 2.1.1-8 [140 kB]
# Get:224 http://archive.ubuntu.com/ubuntu bionic/universe amd64 openmpi-bin amd64 2.1.1-8 [88.2 kB]
# Get:225 http://archive.ubuntu.com/ubuntu bionic/main amd64 python3-numpy amd64 1:1.13.3-2ubuntu1 [1943 kB]
# Get:226 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 python3-opencv amd64 3.2.0+dfsg-4ubuntu0.1 [534 kB]
# Get:227 http://archive.ubuntu.com/ubuntu bionic/universe amd64 i965-va-driver amd64 2.1.0-0ubuntu1 [925 kB]
# Get:228 http://archive.ubuntu.com/ubuntu bionic/universe amd64 va-driver-all amd64 2.1.0-3 [4376 B]
# Get:229 http://archive.ubuntu.com/ubuntu bionic/main amd64 vdpau-driver-all amd64 1.1.1-3ubuntu1 [4674 B]
# Get:230 http://archive.ubuntu.com/ubuntu bionic/universe amd64 proj-bin amd64 4.9.3-2 [32.3 kB]
# Fetched 131 MB in 6s (21.8 MB/s)
# Selecting previously unselected package libogg0:amd64.
# (Reading database ... 15752 files and directories currently installed.)
# Preparing to unpack .../000-libogg0_1.3.2-1_amd64.deb ...
# Unpacking libogg0:amd64 (1.3.2-1) ...
# Selecting previously unselected package libxft2:amd64.
# Preparing to unpack .../001-libxft2_2.3.2-1_amd64.deb ...
# Unpacking libxft2:amd64 (2.3.2-1) ...
# Selecting previously unselected package libxinerama1:amd64.
# Preparing to unpack .../002-libxinerama1_2%3a1.1.3-1_amd64.deb ...
# Unpacking libxinerama1:amd64 (2:1.1.3-1) ...
# Selecting previously unselected package libxss1:amd64.
# Preparing to unpack .../003-libxss1_1%3a1.2.2-1_amd64.deb ...
# Unpacking libxss1:amd64 (1:1.2.2-1) ...
# Selecting previously unselected package libxxf86vm1:amd64.
# Preparing to unpack .../004-libxxf86vm1_1%3a1.1.4-1_amd64.deb ...
# Unpacking libxxf86vm1:amd64 (1:1.1.4-1) ...
# Selecting previously unselected package poppler-data.
# Preparing to unpack .../005-poppler-data_0.4.8-2_all.deb ...
# Unpacking poppler-data (0.4.8-2) ...
# Selecting previously unselected package libjson-c3:amd64.
# Preparing to unpack .../006-libjson-c3_0.12.1-1.3ubuntu0.3_amd64.deb ...
# Unpacking libjson-c3:amd64 (0.12.1-1.3ubuntu0.3) ...
# Selecting previously unselected package tzdata.
# Preparing to unpack .../007-tzdata_2022a-0ubuntu0.18.04_all.deb ...
# Unpacking tzdata (2022a-0ubuntu0.18.04) ...
# Selecting previously unselected package xkb-data.
# Preparing to unpack .../008-xkb-data_2.23.1-1ubuntu1.18.04.1_all.deb ...
# Unpacking xkb-data (2.23.1-1ubuntu1.18.04.1) ...
# Selecting previously unselected package libdrm-common.
# Preparing to unpack .../009-libdrm-common_2.4.101-2~18.04.1_all.deb ...
# Unpacking libdrm-common (2.4.101-2~18.04.1) ...
# Selecting previously unselected package libdrm2:amd64.
# Preparing to unpack .../010-libdrm2_2.4.101-2~18.04.1_amd64.deb ...
# Unpacking libdrm2:amd64 (2.4.101-2~18.04.1) ...
# Selecting previously unselected package libnuma1:amd64.
# Preparing to unpack .../011-libnuma1_2.0.11-2.1ubuntu0.1_amd64.deb ...
# Unpacking libnuma1:amd64 (2.0.11-2.1ubuntu0.1) ...
# Selecting previously unselected package libusb-1.0-0:amd64.
# Preparing to unpack .../012-libusb-1.0-0_2%3a1.0.21-2_amd64.deb ...
# Unpacking libusb-1.0-0:amd64 (2:1.0.21-2) ...
# Selecting previously unselected package hicolor-icon-theme.
# Preparing to unpack .../013-hicolor-icon-theme_0.17-2_all.deb ...
# Unpacking hicolor-icon-theme (0.17-2) ...
# Selecting previously unselected package libgdk-pixbuf2.0-common.
# Preparing to unpack .../014-libgdk-pixbuf2.0-common_2.36.11-2_all.deb ...
# Unpacking libgdk-pixbuf2.0-common (2.36.11-2) ...
# Selecting previously unselected package libgdk-pixbuf2.0-0:amd64.
# Preparing to unpack .../015-libgdk-pixbuf2.0-0_2.36.11-2_amd64.deb ...
# Unpacking libgdk-pixbuf2.0-0:amd64 (2.36.11-2) ...
# Selecting previously unselected package gtk-update-icon-cache.
# Preparing to unpack .../016-gtk-update-icon-cache_3.22.30-1ubuntu4_amd64.deb ...
# No diversion 'diversion of /usr/sbin/update-icon-caches to /usr/sbin/update-icon-caches.gtk2 by libgtk-3-bin', none removed.
# No diversion 'diversion of /usr/share/man/man8/update-icon-caches.8.gz to /usr/share/man/man8/update-icon-caches.gtk2.8.gz by libgtk-3-bin', none removed.
# Unpacking gtk-update-icon-cache (3.22.30-1ubuntu4) ...
# Selecting previously unselected package libcroco3:amd64.
# Preparing to unpack .../017-libcroco3_0.6.12-2_amd64.deb ...
# Unpacking libcroco3:amd64 (0.6.12-2) ...
# Selecting previously unselected package librsvg2-2:amd64.
# Preparing to unpack .../018-librsvg2-2_2.40.20-2ubuntu0.2_amd64.deb ...
# Unpacking librsvg2-2:amd64 (2.40.20-2ubuntu0.2) ...
# Selecting previously unselected package librsvg2-common:amd64.
# Preparing to unpack .../019-librsvg2-common_2.40.20-2ubuntu0.2_amd64.deb ...
# Unpacking librsvg2-common:amd64 (2.40.20-2ubuntu0.2) ...
# Selecting previously unselected package humanity-icon-theme.
# Preparing to unpack .../020-humanity-icon-theme_0.6.15_all.deb ...
# Unpacking humanity-icon-theme (0.6.15) ...
# Selecting previously unselected package ubuntu-mono.
# Preparing to unpack .../021-ubuntu-mono_16.10+18.04.20181005-0ubuntu1_all.deb ...
# Unpacking ubuntu-mono (16.10+18.04.20181005-0ubuntu1) ...
# Selecting previously unselected package adwaita-icon-theme.
# Preparing to unpack .../022-adwaita-icon-theme_3.28.0-1ubuntu1_all.deb ...
# Unpacking adwaita-icon-theme (3.28.0-1ubuntu1) ...
# Selecting previously unselected package libatspi2.0-0:amd64.
# Preparing to unpack .../023-libatspi2.0-0_2.28.0-1_amd64.deb ...
# Unpacking libatspi2.0-0:amd64 (2.28.0-1) ...
# Selecting previously unselected package libxtst6:amd64.
# Preparing to unpack .../024-libxtst6_2%3a1.2.3-1_amd64.deb ...
# Unpacking libxtst6:amd64 (2:1.2.3-1) ...
# Selecting previously unselected package at-spi2-core.
# Preparing to unpack .../025-at-spi2-core_2.28.0-1_amd64.deb ...
# Unpacking at-spi2-core (2.28.0-1) ...
# Selecting previously unselected package libdconf1:amd64.
# Preparing to unpack .../026-libdconf1_0.26.0-2ubuntu3_amd64.deb ...
# Unpacking libdconf1:amd64 (0.26.0-2ubuntu3) ...
# Selecting previously unselected package dconf-service.
# Preparing to unpack .../027-dconf-service_0.26.0-2ubuntu3_amd64.deb ...
# Unpacking dconf-service (0.26.0-2ubuntu3) ...
# Selecting previously unselected package dconf-gsettings-backend:amd64.
# Preparing to unpack .../028-dconf-gsettings-backend_0.26.0-2ubuntu3_amd64.deb ...
# Unpacking dconf-gsettings-backend:amd64 (0.26.0-2ubuntu3) ...
# Selecting previously unselected package gdal-data.
# Preparing to unpack .../029-gdal-data_2.2.3+dfsg-2_all.deb ...
# Unpacking gdal-data (2.2.3+dfsg-2) ...
# Selecting previously unselected package libproxy1v5:amd64.
# Preparing to unpack .../030-libproxy1v5_0.4.15-1ubuntu0.2_amd64.deb ...
# Unpacking libproxy1v5:amd64 (0.4.15-1ubuntu0.2) ...
# Selecting previously unselected package glib-networking-common.
# Preparing to unpack .../031-glib-networking-common_2.56.0-1ubuntu0.1_all.deb ...
# Unpacking glib-networking-common (2.56.0-1ubuntu0.1) ...
# Selecting previously unselected package glib-networking-services.
# Preparing to unpack .../032-glib-networking-services_2.56.0-1ubuntu0.1_amd64.deb ...
# Unpacking glib-networking-services (2.56.0-1ubuntu0.1) ...
# Selecting previously unselected package gsettings-desktop-schemas.
# Preparing to unpack .../033-gsettings-desktop-schemas_3.28.0-1ubuntu1_all.deb ...
# Unpacking gsettings-desktop-schemas (3.28.0-1ubuntu1) ...
# Selecting previously unselected package glib-networking:amd64.
# Preparing to unpack .../034-glib-networking_2.56.0-1ubuntu0.1_amd64.deb ...
# Unpacking glib-networking:amd64 (2.56.0-1ubuntu0.1) ...
# Selecting previously unselected package libnl-3-200:amd64.
# Preparing to unpack .../035-libnl-3-200_3.2.29-0ubuntu3_amd64.deb ...
# Unpacking libnl-3-200:amd64 (3.2.29-0ubuntu3) ...
# Selecting previously unselected package libnl-route-3-200:amd64.
# Preparing to unpack .../036-libnl-route-3-200_3.2.29-0ubuntu3_amd64.deb ...
# Unpacking libnl-route-3-200:amd64 (3.2.29-0ubuntu3) ...
# Selecting previously unselected package libibverbs1:amd64.
# Preparing to unpack .../037-libibverbs1_17.1-1ubuntu0.2_amd64.deb ...
# Unpacking libibverbs1:amd64 (17.1-1ubuntu0.2) ...
# Selecting previously unselected package ibverbs-providers:amd64.
# Preparing to unpack .../038-ibverbs-providers_17.1-1ubuntu0.2_amd64.deb ...
# Unpacking ibverbs-providers:amd64 (17.1-1ubuntu0.2) ...
# Selecting previously unselected package libaacs0:amd64.
# Preparing to unpack .../039-libaacs0_0.9.0-1_amd64.deb ...
# Unpacking libaacs0:amd64 (0.9.0-1) ...
# Selecting previously unselected package libaec0:amd64.
# Preparing to unpack .../040-libaec0_0.3.2-2_amd64.deb ...
# Unpacking libaec0:amd64 (0.3.2-2) ...
# Selecting previously unselected package libblas3:amd64.
# Preparing to unpack .../041-libblas3_3.7.1-4ubuntu1_amd64.deb ...
# Unpacking libblas3:amd64 (3.7.1-4ubuntu1) ...
# Selecting previously unselected package libgfortran4:amd64.
# Preparing to unpack .../042-libgfortran4_7.5.0-3ubuntu1~18.04_amd64.deb ...
# Unpacking libgfortran4:amd64 (7.5.0-3ubuntu1~18.04) ...
# Selecting previously unselected package liblapack3:amd64.
# Preparing to unpack .../043-liblapack3_3.7.1-4ubuntu1_amd64.deb ...
# Unpacking liblapack3:amd64 (3.7.1-4ubuntu1) ...
# Selecting previously unselected package libarpack2:amd64.
# Preparing to unpack .../044-libarpack2_3.5.0+real-2_amd64.deb ...
# Unpacking libarpack2:amd64 (3.5.0+real-2) ...
# Selecting previously unselected package libsuperlu5:amd64.
# Preparing to unpack .../045-libsuperlu5_5.2.1+dfsg1-3_amd64.deb ...
# Unpacking libsuperlu5:amd64 (5.2.1+dfsg1-3) ...
# Selecting previously unselected package libarmadillo8.
# Preparing to unpack .../046-libarmadillo8_1%3a8.400.0+dfsg-2_amd64.deb ...
# Unpacking libarmadillo8 (1:8.400.0+dfsg-2) ...
# Selecting previously unselected package libatk1.0-data.
# Preparing to unpack .../047-libatk1.0-data_2.28.1-1_all.deb ...
# Unpacking libatk1.0-data (2.28.1-1) ...
# Selecting previously unselected package libatk1.0-0:amd64.
# Preparing to unpack .../048-libatk1.0-0_2.28.1-1_amd64.deb ...
# Unpacking libatk1.0-0:amd64 (2.28.1-1) ...
# Selecting previously unselected package libatk-bridge2.0-0:amd64.
# Preparing to unpack .../049-libatk-bridge2.0-0_2.26.2-1_amd64.deb ...
# Unpacking libatk-bridge2.0-0:amd64 (2.26.2-1) ...
# Selecting previously unselected package libavahi-common-data:amd64.
# Preparing to unpack .../050-libavahi-common-data_0.7-3.1ubuntu1.3_amd64.deb ...
# Unpacking libavahi-common-data:amd64 (0.7-3.1ubuntu1.3) ...
# Selecting previously unselected package libavahi-common3:amd64.
# Preparing to unpack .../051-libavahi-common3_0.7-3.1ubuntu1.3_amd64.deb ...
# Unpacking libavahi-common3:amd64 (0.7-3.1ubuntu1.3) ...
# Selecting previously unselected package libavahi-client3:amd64.
# Preparing to unpack .../052-libavahi-client3_0.7-3.1ubuntu1.3_amd64.deb ...
# Unpacking libavahi-client3:amd64 (0.7-3.1ubuntu1.3) ...
# Selecting previously unselected package libva2:amd64.
# Preparing to unpack .../053-libva2_2.1.0-3_amd64.deb ...
# Unpacking libva2:amd64 (2.1.0-3) ...
# Selecting previously unselected package libva-drm2:amd64.
# Preparing to unpack .../054-libva-drm2_2.1.0-3_amd64.deb ...
# Unpacking libva-drm2:amd64 (2.1.0-3) ...
# Selecting previously unselected package libxfixes3:amd64.
# Preparing to unpack .../055-libxfixes3_1%3a5.0.3-1_amd64.deb ...
# Unpacking libxfixes3:amd64 (1:5.0.3-1) ...
# Selecting previously unselected package libva-x11-2:amd64.
# Preparing to unpack .../056-libva-x11-2_2.1.0-3_amd64.deb ...
# Unpacking libva-x11-2:amd64 (2.1.0-3) ...
# Selecting previously unselected package libvdpau1:amd64.
# Preparing to unpack .../057-libvdpau1_1.1.1-3ubuntu1_amd64.deb ...
# Unpacking libvdpau1:amd64 (1.1.1-3ubuntu1) ...
# Selecting previously unselected package libavutil55:amd64.
# Preparing to unpack .../058-libavutil55_7%3a3.4.11-0ubuntu0.1_amd64.deb ...
# Unpacking libavutil55:amd64 (7:3.4.11-0ubuntu0.1) ...
# Selecting previously unselected package libcrystalhd3:amd64.
# Preparing to unpack .../059-libcrystalhd3_1%3a0.0~git20110715.fdd2f19-12_amd64.deb ...
# Unpacking libcrystalhd3:amd64 (1:0.0~git20110715.fdd2f19-12) ...
# Selecting previously unselected package libgsm1:amd64.
# Preparing to unpack .../060-libgsm1_1.0.13-4build1_amd64.deb ...
# Unpacking libgsm1:amd64 (1.0.13-4build1) ...
# Selecting previously unselected package libmp3lame0:amd64.
# Preparing to unpack .../061-libmp3lame0_3.100-2_amd64.deb ...
# Unpacking libmp3lame0:amd64 (3.100-2) ...
# Selecting previously unselected package libopenjp2-7:amd64.
# Preparing to unpack .../062-libopenjp2-7_2.3.0-2build0.18.04.1_amd64.deb ...
# Unpacking libopenjp2-7:amd64 (2.3.0-2build0.18.04.1) ...
# Selecting previously unselected package libopus0:amd64.
# Preparing to unpack .../063-libopus0_1.1.2-1ubuntu1_amd64.deb ...
# Unpacking libopus0:amd64 (1.1.2-1ubuntu1) ...
# Selecting previously unselected package libshine3:amd64.
# Preparing to unpack .../064-libshine3_3.1.1-1_amd64.deb ...
# Unpacking libshine3:amd64 (3.1.1-1) ...
# Selecting previously unselected package libsnappy1v5:amd64.
# Preparing to unpack .../065-libsnappy1v5_1.1.7-1_amd64.deb ...
# Unpacking libsnappy1v5:amd64 (1.1.7-1) ...
# Selecting previously unselected package libspeex1:amd64.
# Preparing to unpack .../066-libspeex1_1.2~rc1.2-1ubuntu2.1_amd64.deb ...
# Unpacking libspeex1:amd64 (1.2~rc1.2-1ubuntu2.1) ...
# Selecting previously unselected package libsoxr0:amd64.
# Preparing to unpack .../067-libsoxr0_0.1.2-3_amd64.deb ...
# Unpacking libsoxr0:amd64 (0.1.2-3) ...
# Selecting previously unselected package libswresample2:amd64.
# Preparing to unpack .../068-libswresample2_7%3a3.4.11-0ubuntu0.1_amd64.deb ...
# Unpacking libswresample2:amd64 (7:3.4.11-0ubuntu0.1) ...
# Selecting previously unselected package libtheora0:amd64.
# Preparing to unpack .../069-libtheora0_1.1.1+dfsg.1-14_amd64.deb ...
# Unpacking libtheora0:amd64 (1.1.1+dfsg.1-14) ...
# Selecting previously unselected package libtwolame0:amd64.
# Preparing to unpack .../070-libtwolame0_0.3.13-3_amd64.deb ...
# Unpacking libtwolame0:amd64 (0.3.13-3) ...
# Selecting previously unselected package libvorbis0a:amd64.
# Preparing to unpack .../071-libvorbis0a_1.3.5-4.2_amd64.deb ...
# Unpacking libvorbis0a:amd64 (1.3.5-4.2) ...
# Selecting previously unselected package libvorbisenc2:amd64.
# Preparing to unpack .../072-libvorbisenc2_1.3.5-4.2_amd64.deb ...
# Unpacking libvorbisenc2:amd64 (1.3.5-4.2) ...
# Selecting previously unselected package libvpx5:amd64.
# Preparing to unpack .../073-libvpx5_1.7.0-3ubuntu0.18.04.1_amd64.deb ...
# Unpacking libvpx5:amd64 (1.7.0-3ubuntu0.18.04.1) ...
# Selecting previously unselected package libwavpack1:amd64.
# Preparing to unpack .../074-libwavpack1_5.1.0-2ubuntu1.5_amd64.deb ...
# Unpacking libwavpack1:amd64 (5.1.0-2ubuntu1.5) ...
# Selecting previously unselected package libwebpmux3:amd64.
# Preparing to unpack .../075-libwebpmux3_0.6.1-2ubuntu0.18.04.1_amd64.deb ...
# Unpacking libwebpmux3:amd64 (0.6.1-2ubuntu0.18.04.1) ...
# Selecting previously unselected package libx264-152:amd64.
# Preparing to unpack .../076-libx264-152_2%3a0.152.2854+gite9a5903-2_amd64.deb ...
# Unpacking libx264-152:amd64 (2:0.152.2854+gite9a5903-2) ...
# ...
# Preparing to unpack .../218-libopencv-contrib3.2_3.2.0+dfsg-4ubuntu0.1_amd64.deb ...
# Unpacking libopencv-contrib3.2:amd64 (3.2.0+dfsg-4ubuntu0.1) ...
# Selecting previously unselected package libxcb-xfixes0:amd64.
# Preparing to unpack .../219-libxcb-xfixes0_1.13-2~ubuntu18.04_amd64.deb ...
# Unpacking libxcb-xfixes0:amd64 (1.13-2~ubuntu18.04) ...
# Selecting previously unselected package mesa-va-drivers:amd64.
# Preparing to unpack .../220-mesa-va-drivers_20.0.8-0ubuntu1~18.04.1_amd64.deb ...
# Unpacking mesa-va-drivers:amd64 (20.0.8-0ubuntu1~18.04.1) ...
# Selecting previously unselected package mesa-vdpau-drivers:amd64.
# Preparing to unpack .../221-mesa-vdpau-drivers_20.0.8-0ubuntu1~18.04.1_amd64.deb ...
# Unpacking mesa-vdpau-drivers:amd64 (20.0.8-0ubuntu1~18.04.1) ...
# Selecting previously unselected package openmpi-common.
# Preparing to unpack .../222-openmpi-common_2.1.1-8_all.deb ...
# Unpacking openmpi-common (2.1.1-8) ...
# Selecting previously unselected package openmpi-bin.
# Preparing to unpack .../223-openmpi-bin_2.1.1-8_amd64.deb ...
# Unpacking openmpi-bin (2.1.1-8) ...
# Selecting previously unselected package python3-numpy.
# Preparing to unpack .../224-python3-numpy_1%3a1.13.3-2ubuntu1_amd64.deb ...
# Unpacking python3-numpy (1:1.13.3-2ubuntu1) ...
# Selecting previously unselected package python3-opencv.
# Preparing to unpack .../225-python3-opencv_3.2.0+dfsg-4ubuntu0.1_amd64.deb ...
# Unpacking python3-opencv (3.2.0+dfsg-4ubuntu0.1) ...
# Selecting previously unselected package i965-va-driver:amd64.
# Preparing to unpack .../226-i965-va-driver_2.1.0-0ubuntu1_amd64.deb ...
# Unpacking i965-va-driver:amd64 (2.1.0-0ubuntu1) ...
# Selecting previously unselected package va-driver-all:amd64.
# Preparing to unpack .../227-va-driver-all_2.1.0-3_amd64.deb ...
# Unpacking va-driver-all:amd64 (2.1.0-3) ...
# Selecting previously unselected package vdpau-driver-all:amd64.
# Preparing to unpack .../228-vdpau-driver-all_1.1.1-3ubuntu1_amd64.deb ...
# Unpacking vdpau-driver-all:amd64 (1.1.1-3ubuntu1) ...
# Selecting previously unselected package proj-bin.
# Preparing to unpack .../229-proj-bin_4.9.3-2_amd64.deb ...
# Unpacking proj-bin (4.9.3-2) ...
# Setting up libxi6:amd64 (2:1.7.9-1) ...
# Setting up libminizip1:amd64 (1.1-8build1) ...
# Setting up libxcb-present0:amd64 (1.13-2~ubuntu18.04) ...
# Setting up libglvnd0:amd64 (1.0.0-2ubuntu2.3) ...
# Setting up libxinerama1:amd64 (2:1.1.3-1) ...
# Setting up libxcb-dri2-0:amd64 (1.13-2~ubuntu18.04) ...
# Setting up libxcb-dri3-0:amd64 (1.13-2~ubuntu18.04) ...
# Setting up libxcb-glx0:amd64 (1.13-2~ubuntu18.04) ...
# Setting up libaec0:amd64 (0.3.2-2) ...
# Setting up libtwolame0:amd64 (0.3.13-3) ...
# Setting up libdap25:amd64 (3.19.1-2build1) ...
# Setting up libx264-152:amd64 (2:0.152.2854+gite9a5903-2) ...
# Setting up libraw1394-11:amd64 (2.1.2-1) ...
# Setting up libjson-glib-1.0-common (1.4.2-3ubuntu0.18.04.1) ...
# Setting up libxcb-xfixes0:amd64 (1.13-2~ubuntu18.04) ...
# Setting up libopenjp2-7:amd64 (2.3.0-2build0.18.04.1) ...
# Setting up libllvm10:amd64 (1:10.0.0-4ubuntu1~18.04.2) ...
# Setting up libqhull7:amd64 (2015.2-4) ...
# Setting up libodbc1:amd64 (2.3.4-1.1ubuntu3) ...
# Setting up glib-networking-common (2.56.0-1ubuntu0.1) ...
# Setting up libxdamage1:amd64 (1:1.1.4-3) ...
# Setting up libxfixes3:amd64 (1:5.0.3-1) ...
# Setting up libgfortran4:amd64 (7.5.0-3ubuntu1~18.04) ...
# Setting up libwavpack1:amd64 (5.1.0-2ubuntu1.5) ...
# Setting up liblcms2-2:amd64 (2.9-1ubuntu0.1) ...
# Setting up poppler-data (0.4.8-2) ...
# Setting up libjson-c3:amd64 (0.12.1-1.3ubuntu0.3) ...
# Setting up libaacs0:amd64 (0.9.0-1) ...
# Setting up libnuma1:amd64 (2.0.11-2.1ubuntu0.1) ...
# Setting up tzdata (2022a-0ubuntu0.18.04) ...
#
# Current default time zone: 'Etc/UTC'
# Local time is now:      Sun Jun 12 12:44:39 UTC 2022.
# Universal Time is now:  Sun Jun 12 12:44:39 UTC 2022.
# Run 'dpkg-reconfigure tzdata' if you wish to change it.
#
# Setting up libcharls1:amd64 (1.1.0+dfsg-2) ...
# Setting up libtbb2:amd64 (2017~U7-8) ...
# Setting up libatspi2.0-0:amd64 (2.28.0-1) ...
# Setting up libgeos-3.6.2:amd64 (3.6.2-1build2) ...
# Setting up libsoxr0:amd64 (0.1.2-3) ...
# Setting up libssh-gcrypt-4:amd64 (0.8.0~20170825.94fa1e38-1ubuntu0.7) ...
# Setting up libxss1:amd64 (1:1.2.2-1) ...
# Setting up mysql-common (5.8+1.0.4) ...
# update-alternatives: using /etc/mysql/my.cnf.fallback to provide /etc/mysql/my.cnf (my.cnf) in auto mode
# Setting up libxshmfence1:amd64 (1.3-1) ...
# Setting up libopencv-core3.2:amd64 (3.2.0+dfsg-4ubuntu0.1) ...
# Setting up libwayland-client0:amd64 (1.16.0-1ubuntu1.1~18.04.3) ...
# Setting up libcairo-gobject2:amd64 (1.15.10-2ubuntu0.1) ...
# Setting up xkb-data (2.23.1-1ubuntu1.18.04.1) ...
# Setting up libproxy1v5:amd64 (0.4.15-1ubuntu0.2) ...
# Setting up libbluray2:amd64 (1:1.0.2-3) ...
# Setting up libvdpau1:amd64 (1.1.1-3ubuntu1) ...
# Setting up libsocket++1:amd64 (1.12.13-9) ...
# Setting up libgdk-pixbuf2.0-common (2.36.11-2) ...
# Setting up glib-networking-services (2.56.0-1ubuntu0.1) ...
# Setting up libshine3:amd64 (3.1.1-1) ...
# Setting up libgif7:amd64 (5.1.4-2ubuntu0.1) ...
# Setting up libva2:amd64 (2.1.0-3) ...
# Setting up libglapi-mesa:amd64 (20.0.8-0ubuntu1~18.04.1) ...
# Setting up libepsilon1:amd64 (0.9.2+dfsg-2) ...
# Setting up libspeex1:amd64 (1.2~rc1.2-1ubuntu2.1) ...
# Setting up libxvidcore4:amd64 (2:1.3.5-1) ...
# Setting up libhwloc5:amd64 (1.11.9-1) ...
# Setting up libnspr4:amd64 (2:4.18-1ubuntu1) ...
# Setting up libgphoto2-l10n (2.5.16-2) ...
# Setting up libfreexl1:amd64 (1.0.5-1) ...
# Setting up libopus0:amd64 (1.1.2-1ubuntu1) ...
# Setting up libxtst6:amd64 (2:1.2.3-1) ...
# Setting up libx265-146:amd64 (2.6-3) ...
# Setting up libfyba0:amd64 (4.1.1-3) ...
# Setting up libdrm-common (2.4.101-2~18.04.1) ...
# Setting up libjson-glib-1.0-0:amd64 (1.4.2-3ubuntu0.18.04.1) ...
# Setting up libcroco3:amd64 (0.6.12-2) ...
# Setting up libxcb-sync1:amd64 (1.13-2~ubuntu18.04) ...
# Setting up liblept5 (1.75.3-3) ...
# Setting up libpsm-infinipath1 (3.3+20.604758e7-5) ...
# update-alternatives: using /usr/lib/libpsm1/libpsm_infinipath.so.1.16 to provide /usr/lib/x86_64-linux-gnu/libpsm_infinipath.so.1 (libpsm_infinipath.so.1) in auto mode
# Setting up libdapclient6v5:amd64 (3.19.1-2build1) ...
# Setting up libogg0:amd64 (1.3.2-1) ...
# Setting up gdal-data (2.2.3+dfsg-2) ...
# Setting up libilmbase12:amd64 (2.2.0-11ubuntu2) ...
# Setting up libatk1.0-data (2.28.1-1) ...
# Setting up libgeos-c1v5:amd64 (3.6.2-1build2) ...
# Setting up libx11-xcb1:amd64 (2:1.6.4-3ubuntu0.4) ...
# Setting up libmp3lame0:amd64 (3.100-2) ...
# Setting up libblas3:amd64 (3.7.1-4ubuntu1) ...
# update-alternatives: using /usr/lib/x86_64-linux-gnu/blas/libblas.so.3 to provide /usr/lib/x86_64-linux-gnu/libblas.so.3 (libblas.so.3-x86_64-linux-gnu) in auto mode
# Setting up libxcursor1:amd64 (1:1.1.15-1) ...
# Setting up libpq5:amd64 (10.21-0ubuntu0.18.04.1) ...
# Setting up libusb-1.0-0:amd64 (2:1.0.21-2) ...
# Setting up libcrystalhd3:amd64 (1:0.0~git20110715.fdd2f19-12) ...
# Setting up openmpi-common (2.1.1-8) ...
# Setting up libepoxy0:amd64 (1.4.3-1) ...
# Setting up libatk1.0-0:amd64 (2.28.1-1) ...
# Setting up libgdcm2.8:amd64 (2.8.4-1build2) ...
# Setting up libwebpmux3:amd64 (0.6.1-2ubuntu0.18.04.1) ...
# Setting up libsnappy1v5:amd64 (1.1.7-1) ...
# Setting up libatk-bridge2.0-0:amd64 (2.26.2-1) ...
# Setting up libopencv-ml3.2:amd64 (3.2.0+dfsg-4ubuntu0.1) ...
# Setting up libdconf1:amd64 (0.26.0-2ubuntu3) ...
# Setting up libxcomposite1:amd64 (1:0.4.4-2) ...
# Setting up libzvbi-common (0.2.35-13) ...
# Setting up libpciaccess0:amd64 (0.14-1) ...
# Setting up libsensors4:amd64 (1:3.4.0-4ubuntu0.1) ...
# Setting up libxkbcommon0:amd64 (0.8.2-1~ubuntu18.04.1) ...
# Setting up libopencv-imgproc3.2:amd64 (3.2.0+dfsg-4ubuntu0.1) ...
# Setting up libvpx5:amd64 (1.7.0-3ubuntu0.18.04.1) ...
# Setting up libmysqlclient20:amd64 (5.7.38-0ubuntu0.18.04.1) ...
# Setting up libopencv-flann3.2:amd64 (3.2.0+dfsg-4ubuntu0.1) ...
# Setting up libgme0:amd64 (0.6.2-1) ...
# Setting up libtcl8.6:amd64 (8.6.8+dfsg-3) ...
# Setting up libcolord2:amd64 (1.3.3-2build1) ...
# Setting up libbdplus0:amd64 (0.1.2-2) ...
# Setting up ocl-icd-libopencl1:amd64 (2.2.11-1ubuntu1) ...
# Setting up libxxf86vm1:amd64 (1:1.1.4-1) ...
# Setting up libhdf4-0-alt (4.2.13-2) ...
# Setting up libzvbi0:amd64 (0.2.35-13) ...
# Setting up libxft2:amd64 (2.3.2-1) ...
# Setting up libnl-3-200:amd64 (3.2.29-0ubuntu3) ...
# Setting up libpython2.7-minimal:amd64 (2.7.17-1~18.04ubuntu1.7) ...
# Setting up libvorbis0a:amd64 (1.3.5-4.2) ...
# Setting up libopencv-video3.2:amd64 (3.2.0+dfsg-4ubuntu0.1) ...
# Setting up libtheora0:amd64 (1.1.1+dfsg.1-14) ...
# Setting up libmpg123-0:amd64 (1.25.10-1) ...
# Setting up hicolor-icon-theme (0.17-2) ...
# Setting up libexif12:amd64 (0.6.21-4ubuntu0.6) ...
# Setting up libwayland-cursor0:amd64 (1.16.0-1ubuntu1.1~18.04.3) ...
# Setting up libgsm1:amd64 (1.0.13-4build1) ...
# Setting up libwayland-egl1:amd64 (1.16.0-1ubuntu1.1~18.04.3) ...
# Setting up libpython2.7-stdlib:amd64 (2.7.17-1~18.04ubuntu1.7) ...
# Setting up libxrandr2:amd64 (2:1.5.1-1) ...
# Setting up libxerces-c3.2:amd64 (3.2.0+debian-2) ...
# Setting up liburiparser1:amd64 (0.8.4-1+deb9u2build0.18.04.1) ...
# Setting up libavahi-common-data:amd64 (0.7-3.1ubuntu1.3) ...
# Setting up libsz2:amd64 (0.3.2-2) ...
# Setting up proj-data (4.9.3-2) ...
# Setting up libjsoncpp1:amd64 (1.7.4-3) ...
# Setting up libvorbisfile3:amd64 (1.3.5-4.2) ...
# Setting up libopencv-photo3.2:amd64 (3.2.0+dfsg-4ubuntu0.1) ...
# Setting up libgphoto2-port12:amd64 (2.5.16-2) ...
# Setting up libproj12:amd64 (4.9.3-2) ...
# Setting up libhdf5-100:amd64 (1.10.0-patch1+docs-4) ...
# Setting up dconf-service (0.26.0-2ubuntu3) ...
# Setting up libopenmpt0:amd64 (0.3.6-1) ...
# Setting up liblapack3:amd64 (3.7.1-4ubuntu1) ...
# update-alternatives: using /usr/lib/x86_64-linux-gnu/lapack/liblapack.so.3 to provide /usr/lib/x86_64-linux-gnu/liblapack.so.3 (liblapack.so.3-x86_64-linux-gnu) in auto mode
# Setting up at-spi2-core (2.28.0-1) ...
# Setting up libtk8.6:amd64 (8.6.8-4) ...
# Setting up libgdk-pixbuf2.0-0:amd64 (2.36.11-2) ...
# Setting up libtesseract4 (4.00~git2288-10f4998a-2) ...
# Setting up libgdk-pixbuf2.0-bin (2.36.11-2) ...
# Setting up libgphoto2-6:amd64 (2.5.16-2) ...
# Setting up libnss3:amd64 (2:3.35-2ubuntu2.14) ...
# Setting up libdc1394-22:amd64 (2.2.5-1) ...
# Setting up libnl-route-3-200:amd64 (3.2.29-0ubuntu3) ...
# Setting up libopenexr22:amd64 (2.2.0-11.1ubuntu1.9) ...
# Setting up libsuperlu5:amd64 (5.2.1+dfsg1-3) ...
# Setting up libkmlbase1:amd64 (1.3.0-5) ...
# Setting up libdrm2:amd64 (2.4.101-2~18.04.1) ...
# Setting up libogdi3.2 (3.2.0+ds-2) ...
# Setting up libpoppler73:amd64 (0.62.0-2ubuntu2.12) ...
# Setting up libhwloc-plugins (1.11.9-1) ...
# Setting up libdrm-intel1:amd64 (2.4.101-2~18.04.1) ...
# Setting up gtk-update-icon-cache (3.22.30-1ubuntu4) ...
# Setting up proj-bin (4.9.3-2) ...
# Setting up libva-drm2:amd64 (2.1.0-3) ...
# Setting up libpython2.7:amd64 (2.7.17-1~18.04ubuntu1.7) ...
# Setting up libgeotiff2:amd64 (1.4.2-2build1) ...
# Setting up libnetcdf13:amd64 (1:4.6.0-2build1) ...
# Setting up libopencv-shape3.2:amd64 (3.2.0+dfsg-4ubuntu0.1) ...
# Setting up libspatialite7:amd64 (4.3.0a-5build1) ...
# Setting up libarpack2:amd64 (3.5.0+real-2) ...
# Setting up libkmldom1:amd64 (1.3.0-5) ...
# Setting up libavahi-common3:amd64 (0.7-3.1ubuntu1.3) ...
# Setting up libdrm-radeon1:amd64 (2.4.101-2~18.04.1) ...
# Setting up libvorbisenc2:amd64 (1.3.5-4.2) ...
# Setting up libva-x11-2:amd64 (2.1.0-3) ...
# Setting up libdrm-nouveau2:amd64 (2.4.101-2~18.04.1) ...
# Setting up dconf-gsettings-backend:amd64 (0.26.0-2ubuntu3) ...
# Setting up libibverbs1:amd64 (17.1-1ubuntu0.2) ...
# Setting up libnetcdf-c++4 (4.2-8) ...
# Setting up librsvg2-2:amd64 (2.40.20-2ubuntu0.2) ...
# Setting up libavutil55:amd64 (7:3.4.11-0ubuntu0.1) ...
# Setting up gsettings-desktop-schemas (3.28.0-1ubuntu1) ...
# Setting up libdrm-amdgpu1:amd64 (2.4.101-2~18.04.1) ...
# Setting up libgtk-3-common (3.22.30-1ubuntu4) ...
# Setting up python3-numpy (1:1.13.3-2ubuntu1) ...
# Setting up mesa-vdpau-drivers:amd64 (20.0.8-0ubuntu1~18.04.1) ...
# Setting up libgl1-mesa-dri:amd64 (20.0.8-0ubuntu1~18.04.1) ...
# Setting up librdmacm1:amd64 (17.1-1ubuntu0.2) ...
# Setting up libswresample2:amd64 (7:3.4.11-0ubuntu0.1) ...
# Setting up librsvg2-common:amd64 (2.40.20-2ubuntu0.2) ...
# Setting up libarmadillo8 (1:8.400.0+dfsg-2) ...
# Setting up i965-va-driver:amd64 (2.1.0-0ubuntu1) ...
# Setting up libkmlengine1:amd64 (1.3.0-5) ...
# Setting up libswscale4:amd64 (7:3.4.11-0ubuntu0.1) ...
# Setting up ibverbs-providers:amd64 (17.1-1ubuntu0.2) ...
# Setting up mesa-va-drivers:amd64 (20.0.8-0ubuntu1~18.04.1) ...
# Setting up libavahi-client3:amd64 (0.7-3.1ubuntu1.3) ...
# Setting up libglx-mesa0:amd64 (20.0.8-0ubuntu1~18.04.1) ...
# Setting up libcups2:amd64 (2.2.7-1ubuntu2.9) ...
# Setting up vdpau-driver-all:amd64 (1.1.1-3ubuntu1) ...
# Setting up libfabric1 (1.5.3-1) ...
# Setting up libavcodec57:amd64 (7:3.4.11-0ubuntu0.1) ...
# Setting up va-driver-all:amd64 (2.1.0-3) ...
# Setting up libopenmpi2:amd64 (2.1.1-8) ...
# Setting up libglx0:amd64 (1.0.0-2ubuntu2.3) ...
# Setting up libchromaprint1:amd64 (1.4.3-1) ...
# Setting up libhdf5-openmpi-100:amd64 (1.10.0-patch1+docs-4) ...
# Setting up openmpi-bin (2.1.1-8) ...
# update-alternatives: using /usr/bin/mpirun.openmpi to provide /usr/bin/mpirun (mpirun) in auto mode
# update-alternatives: warning: skip creation of /usr/share/man/man1/mpirun.1.gz because associated file /usr/share/man/man1/mpirun.openmpi.1.gz (of link group mpirun) doesn't exist
# update-alternatives: warning: skip creation of /usr/share/man/man1/mpiexec.1.gz because associated file /usr/share/man/man1/mpiexec.openmpi.1.gz (of link group mpirun) doesn't exist
# Setting up libgl1:amd64 (1.0.0-2ubuntu2.3) ...
# Setting up libavformat57:amd64 (7:3.4.11-0ubuntu0.1) ...
# Setting up libgl2ps1.4 (1.4.0+dfsg1-1) ...
# Setting up libgl1-mesa-glx:amd64 (20.0.8-0ubuntu1~18.04.1) ...
# Setting up odbcinst1debian2:amd64 (2.3.4-1.1ubuntu3) ...
# Setting up adwaita-icon-theme (3.28.0-1ubuntu1) ...
# update-alternatives: using /usr/share/icons/Adwaita/cursor.theme to provide /usr/share/icons/default/index.theme (x-cursor-theme) in auto mode
# Setting up odbcinst (2.3.4-1.1ubuntu3) ...
# Setting up libgdal20 (2.2.3+dfsg-2) ...
# Setting up humanity-icon-theme (0.6.15) ...
# Setting up libopencv-imgcodecs3.2:amd64 (3.2.0+dfsg-4ubuntu0.1) ...
# Setting up libvtk6.3 (6.3.0+dfsg1-11build1) ...
# Setting up libopencv-videoio3.2:amd64 (3.2.0+dfsg-4ubuntu0.1) ...
# Setting up ubuntu-mono (16.10+18.04.20181005-0ubuntu1) ...
# Setting up libopencv-viz3.2:amd64 (3.2.0+dfsg-4ubuntu0.1) ...
# Setting up libopencv-superres3.2:amd64 (3.2.0+dfsg-4ubuntu0.1) ...
# Processing triggers for fontconfig (2.12.6-0ubuntu2) ...
# Processing triggers for libglib2.0-0:amd64 (2.56.4-0ubuntu0.18.04.8) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.4) ...
# Setting up glib-networking:amd64 (2.56.0-1ubuntu0.1) ...
# Setting up libsoup2.4-1:amd64 (2.62.1-1ubuntu0.4) ...
# Setting up libsoup-gnome2.4-1:amd64 (2.62.1-1ubuntu0.4) ...
# Setting up librest-0.7-0:amd64 (0.8.0-2) ...
# Setting up libgtk-3-0:amd64 (3.22.30-1ubuntu4) ...
# Setting up libgtk-3-bin (3.22.30-1ubuntu4) ...
# Setting up libopencv-highgui3.2:amd64 (3.2.0+dfsg-4ubuntu0.1) ...
# Setting up libopencv-objdetect3.2:amd64 (3.2.0+dfsg-4ubuntu0.1) ...
# Setting up libopencv-features2d3.2:amd64 (3.2.0+dfsg-4ubuntu0.1) ...
# Setting up libopencv-calib3d3.2:amd64 (3.2.0+dfsg-4ubuntu0.1) ...
# Setting up libopencv-stitching3.2:amd64 (3.2.0+dfsg-4ubuntu0.1) ...
# Setting up libopencv-videostab3.2:amd64 (3.2.0+dfsg-4ubuntu0.1) ...
# Setting up libopencv-contrib3.2:amd64 (3.2.0+dfsg-4ubuntu0.1) ...
# Setting up python3-opencv (3.2.0+dfsg-4ubuntu0.1) ...
# Processing triggers for libgdk-pixbuf2.0-0:amd64 (2.36.11-2) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.4) ...
# Requirement already satisfied: opencv-python in /opt/conda/lib/python3.7/site-packages (4.5.4.58)
# Requirement already satisfied: numpy>=1.14.5 in /opt/conda/lib/python3.7/site-packages (from opencv-python) (1.21.2)
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
# debconf: delaying package configuration, since apt-utils is not installed

# %%
# Install dependencies and 
# !pip install albumentations==0.4.6
# !pip install pycocotools --quiet
# !pwd
# Out:
# Collecting albumentations==0.4.6
#   Downloading albumentations-0.4.6.tar.gz (117 kB)
#      |████████████████████████████████| 117 kB 29.4 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.11.1 in /opt/conda/lib/python3.7/site-packages (from albumentations==0.4.6) (1.21.2)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.7/site-packages (from albumentations==0.4.6) (1.7.2)
# Collecting imgaug>=0.4.0
#   Downloading imgaug-0.4.0-py2.py3-none-any.whl (948 kB)
#      |████████████████████████████████| 948 kB 29.6 MB/s eta 0:00:01     |█████████████████████████▎      | 747 kB 29.6 MB/s eta 0:00:01
# Requirement already satisfied: PyYAML in /opt/conda/lib/python3.7/site-packages (from albumentations==0.4.6) (5.4.1)
# Requirement already satisfied: opencv-python>=4.1.1 in /opt/conda/lib/python3.7/site-packages (from albumentations==0.4.6) (4.5.4.58)
# Requirement already satisfied: imageio in /opt/conda/lib/python3.7/site-packages (from imgaug>=0.4.0->albumentations==0.4.6) (2.10.3)
# Requirement already satisfied: six in /opt/conda/lib/python3.7/site-packages (from imgaug>=0.4.0->albumentations==0.4.6) (1.16.0)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.7/site-packages (from imgaug>=0.4.0->albumentations==0.4.6) (3.4.3)
# Collecting Shapely
#   Downloading Shapely-1.8.2-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (2.0 MB)
#      |████████████████████████████████| 2.0 MB 27.2 MB/s eta 0:00:01
# Requirement already satisfied: Pillow in /opt/conda/lib/python3.7/site-packages (from imgaug>=0.4.0->albumentations==0.4.6) (8.4.0)
# Requirement already satisfied: scikit-image>=0.14.2 in /opt/conda/lib/python3.7/site-packages (from imgaug>=0.4.0->albumentations==0.4.6) (0.18.3)
# Requirement already satisfied: PyWavelets>=1.1.1 in /opt/conda/lib/python3.7/site-packages (from scikit-image>=0.14.2->imgaug>=0.4.0->albumentations==0.4.6) (1.2.0)
# Requirement already satisfied: networkx>=2.0 in /opt/conda/lib/python3.7/site-packages (from scikit-image>=0.14.2->imgaug>=0.4.0->albumentations==0.4.6) (2.6.3)
# Requirement already satisfied: tifffile>=2019.7.26 in /opt/conda/lib/python3.7/site-packages (from scikit-image>=0.14.2->imgaug>=0.4.0->albumentations==0.4.6) (2021.11.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.7/site-packages (from matplotlib->imgaug>=0.4.0->albumentations==0.4.6) (1.3.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/lib/python3.7/site-packages (from matplotlib->imgaug>=0.4.0->albumentations==0.4.6) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.7/site-packages (from matplotlib->imgaug>=0.4.0->albumentations==0.4.6) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.7/site-packages (from matplotlib->imgaug>=0.4.0->albumentations==0.4.6) (0.11.0)
# Building wheels for collected packages: albumentations
#   Building wheel for albumentations (setup.py) ... done
#   Created wheel for albumentations: filename=albumentations-0.4.6-py3-none-any.whl size=65173 sha256=720e993651aea51a3e06d162e1fb89e0b71e0866318f5e9047ae30578f796796
#   Stored in directory: /root/.cache/pip/wheels/cf/34/0f/cb2a5f93561a181a4bcc84847ad6aaceea8b5a3127469616cc
# Successfully built albumentations
# Installing collected packages: Shapely, imgaug, albumentations
#   Attempting uninstall: albumentations
#     Found existing installation: albumentations 1.1.0
#     Uninstalling albumentations-1.1.0:
#       Successfully uninstalled albumentations-1.1.0
# Successfully installed Shapely-1.8.2 albumentations-0.4.6 imgaug-0.4.0
# /notebooks/ml635e2/ml635h

# %%
# %cd ..
# !cp vision/references/detection/utils.py ./
# !cp vision/references/detection/transforms.py ./
# !cp vision/references/detection/coco_eval.py ./
# !cp vision/references/detection/engine.py ./
# !cp vision/references/detection/coco_utils.py ./
# !pwd

# %% [markdown]
# Lets import the libraries

# %%
# basic python and ML Libraries
import os
import random
import numpy as np
import pandas as pd

# for ignoring warnings
import warnings
warnings.filterwarnings('ignore')

# We will be reading images using OpenCV
import cv2

# matplotlib for visualization
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# torchvision libraries
import torch
import torchvision
from torchvision import transforms as torchtrans  
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor

# helper libraries
from engine import train_one_epoch, evaluate
import utils
import transforms as T

# for image augmentations
import albumentations as A
from albumentations.pytorch.transforms import ToTensorV2

# %% [markdown]
# ## The Dataset

# %% [markdown]
# Having a good dataset is essential to training an accurate model. However, just possessing the dataset is not enough. We must pre-process it so that it can be fed to the neural network - and then understood by it.
#
# Finding an existing dataset can sometimes be very difficult. When searching for your dataset you may run into the following problems:
#
# * **Broken links**: even if someone has open-sourced something, links they previously had to their datasets often end up becoming stale.
# * **Poor Open-Source Practice**: some "open-source" dataset providers will insist on you contributing to the dataset to be provided access.
#
# However, keep searching! Here's some tricks:
#
# * **Search specific websites**: When searching on Google, you can search specifically on GitHub by searching something like: `cone detection dataset site:github.com`.
# * **Reading other people's code**: Try to find the code of someone else that worked on a similar problem, and see if you can find out what dataset they used! Such as searching: `image classification on traffic cones` and trying to find other notebooks.
#
#
# We found the dataset for this worksop by scouring GitHub repos. It contains 123 annotated images in the training set and
#
# Let's download it!

# %%
# !pwd 
# !apt install wget unrar
# Out:
# /notebooks/ml635e2/635h
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   unrar wget
# 0 upgraded, 2 newly installed, 0 to remove and 76 not upgraded.
# Need to get 445 kB of archives.
# After this operation, 1276 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 wget amd64 1.19.4-1ubuntu2.2 [316 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/multiverse amd64 unrar amd64 1:5.5.8-1 [129 kB]
# Fetched 445 kB in 1s (671 kB/s)
# debconf: delaying package configuration, since apt-utils is not installed
#
# 78Selecting previously unselected package wget.
# (Reading database ... 35823 files and directories currently installed.)
# Preparing to unpack .../wget_1.19.4-1ubuntu2.2_amd64.deb ...
# 7Progress: [  0%] [..........................................................] 87Progress: [  9%] [#####.....................................................] 8Unpacking wget (1.19.4-1ubuntu2.2) ...
# 7Progress: [ 18%] [##########................................................] 87Progress: [ 27%] [###############...........................................] 8Selecting previously unselected package unrar.
# Preparing to unpack .../unrar_1%3a5.5.8-1_amd64.deb ...
# 7Progress: [ 36%] [#####################.....................................] 8Unpacking unrar (1:5.5.8-1) ...
# 7Progress: [ 45%] [##########################................................] 87Progress: [ 55%] [###############################...........................] 8Setting up unrar (1:5.5.8-1) ...
# 7Progress: [ 64%] [####################################......................] 8update-alternatives: using /usr/bin/unrar-nonfree to provide /usr/bin/unrar (unrar) in auto mode
# update-alternatives: warning: skip creation of /usr/share/man/man1/unrar.1.gz because associated file /usr/share/man/man1/unrar-nonfree.1.gz (of link group unrar) doesn't exist
# 7Progress: [ 73%] [##########################################................] 8Setting up wget (1.19.4-1ubuntu2.2) ...
# 7Progress: [ 82%] [###############################################...........] 87Progress: [ 91%] [####################################################......] 8
# 78
# UNRAR 5.50 freeware      Copyright (c) 1993-2017 Alexander Roshal
#
# Cannot open data.rar
# No such file or directory
# No files to extract
# rm: cannot remove 'img/96.jpg': No such file or directory

# %%
# !wget -O data.rar https://www.dropbox.com/sh/ay9wf7ii81q5zif/AADwIb9HkvpBmUDJvKpNl0Xna?dl=0&file_subpath=%2Fimg&preview=data.rar#:~:text=Sign%20up-,Direct,-download
# !unrar x data.rar
# image 96 had no annotations, so we'll delete it!
# !rm img/96.jpg
# !ls -la
# !pwd
# Out:
# UNRAR 5.50 freeware      Copyright (c) 1993-2017 Alexander Roshal
#
#
# Extracting from data.rar
#
# Creating    v-img                                                     OK
# Extracting  v-img/137.jpg                                                0  OK
# Extracting  v-img/137.txt                                                0  OK
# Extracting  v-img/140.jpg                                                0  OK
# Extracting  v-img/140.txt                                                0  OK
# Extracting  v-img/159.jpg                                                1  OK
# Extracting  v-img/159.txt                                                1  OK
# Extracting  v-img/218.jpg                                                2  OK
# Extracting  v-img/218.txt                                                2  OK
# Extracting  v-img/232.jpg                                                2  OK
# Extracting  v-img/232.txt                                                2  OK
# Extracting  v-img/236.jpg                                                2  OK
# Extracting  v-img/236.txt                                                2  OK
# Extracting  v-img/509.jpg                                                3  OK
# Extracting  v-img/509.txt                                                3  OK
# Extracting  v-img/74.jpg                                                 4  OK
# Extracting  v-img/74.txt                                                 4  OK
# Extracting  v-img/80.jpg                                                 4  OK
# Extracting  v-img/80.txt                                                 4  OK
# Extracting  v-img/82.jpg                                                 5  OK
# Extracting  v-img/82.txt                                                 5  OK
# Creating    img                                                       OK
# Extracting  img/1.jpg                                                    5  OK
# Extracting  img/1.txt                                                    5  OK
# Extracting  img/10.jpg                                                   5  OK
# Extracting  img/10.txt                                                   5  OK
# Extracting  img/101.jpg                                                  6  OK
# Extracting  img/101.txt                                                  6  OK
# Extracting  img/102.jpg                                                  7  OK
# Extracting  img/102.txt                                                  7  OK
# Extracting  img/103.jpg                                                  7  OK
# Extracting  img/103.txt                                                  7  OK
# Extracting  img/104.jpg                                                  8  OK
# Extracting  img/104.txt                                                  8  OK
# Extracting  img/105.jpg                                                  9  OK
# Extracting  img/105.txt                                                  9  OK
# Extracting  img/106.jpg                                                  9  OK
# Extracting  img/106.txt                                                  9  OK
# Extracting  img/107.jpg                                                  9  OK
# Extracting  img/107.txt                                                  9  OK
# Extracting  img/108.jpg                                                  9  OK
# Extracting  img/108.txt                                                  9  OK
# Extracting  img/109.jpg                                                 10  OK
# Extracting  img/109.txt                                                 10  OK
# Extracting  img/11.jpg                                                  10  OK
# Extracting  img/11.txt                                                  10  OK
# Extracting  img/111.jpg                                                 10  OK
# Extracting  img/111.txt                                                 10  OK
# Extracting  img/112.jpg                                                 11  OK
# Extracting  img/112.txt                                                 11  OK
# Extracting  img/113.jpg                                                 12  OK
# Extracting  img/113.txt                                                 12  OK
# Extracting  img/115.jpg                                                 12  OK
# Extracting  img/115.txt                                                 12  OK
# Extracting  img/116.jpg                                                 13  OK
# Extracting  img/116.txt                                                 13  OK
# Extracting  img/119.jpg                                                 14  OK
# Extracting  img/119.txt                                                 14  OK
# Extracting  img/12.jpg                                                  14  OK
# Extracting  img/12.txt                                                  14  OK
# Extracting  img/120.jpg                                                 15  OK
# Extracting  img/120.txt                                                 15  OK
# Extracting  img/121.jpg                                                 15  OK
# Extracting  img/121.txt                                                 15  OK
# Extracting  img/123.jpg                                                 16  OK
# Extracting  img/123.txt                                                 16  OK
# Extracting  img/124.jpg                                                 16  OK
# Extracting  img/124.txt                                                 16  OK
# Extracting  img/125.jpg                                                 16  OK
# Extracting  img/125.txt                                                 16  OK
# Extracting  img/126.jpg                                                 16  OK
# Extracting  img/126.txt                                                 16  OK
# Extracting  img/127.jpg                                                 17  OK
# Extracting  img/127.txt                                                 17  OK
# Extracting  img/128.jpg                                                 17  OK
# Extracting  img/128.txt                                                 17  OK
# Extracting  img/129.jpg                                                 18  OK
# Extracting  img/129.txt                                                 18  OK
# Extracting  img/13.jpg                                                  18  OK
# Extracting  img/13.txt                                                  18  OK
# Extracting  img/130.jpg                                                 18  OK
# Extracting  img/130.txt                                                 18  OK
# Extracting  img/131.jpg                                                 18  OK
# Extracting  img/131.txt                                                 18  OK
# Extracting  img/132.jpg                                                 18  OK
# Extracting  img/132.txt                                                 18  OK
# Extracting  img/133.jpg                                                 18  OK
# Extracting  img/133.txt                                                 18  OK
# Extracting  img/134.jpg                                                 18  OK
# Extracting  img/134.txt                                                 18  OK
# Extracting  img/135.jpg                                                 19  OK
# Extracting  img/135.txt                                                 19  OK
# Extracting  img/136.jpg                                                 19  OK
# Extracting  img/136.txt                                                 19  OK
# Extracting  img/138.jpg                                                 19  OK
# Extracting  img/138.txt                                                 19  OK
# Extracting  img/139.jpg                                                 20  OK
# Extracting  img/139.txt                                                 20  OK
# Extracting  img/14.jpg                                                  20  OK
# Extracting  img/14.txt                                                  20  OK
# Extracting  img/141.jpg                                                 20  OK
# Extracting  img/141.txt                                                 20  OK
# Extracting  img/142.jpg                                                 21  OK
# Extracting  img/142.txt                                                 21  OK
# Extracting  img/143.jpg                                                 21  OK
# Extracting  img/143.txt                                                 21  OK
# Extracting  img/148.jpg                                                 21  OK
# Extracting  img/148.txt                                                 21  OK
# Extracting  img/15.jpg                                                  22  OK
# Extracting  img/15.txt                                                  22  OK
# Extracting  img/150.jpg                                                 23  OK
# Extracting  img/150.txt                                                 23  OK
# Extracting  img/151.jpg                                                 23  OK
# Extracting  img/151.txt                                                 23  OK
# Extracting  img/155.jpg                                                 24  OK
# Extracting  img/155.txt                                                 24  OK
# Extracting  img/158.jpg                                                 25  OK
# Extracting  img/158.txt                                                 25  OK
# Extracting  img/161.jpg                                                 26  OK
# Extracting  img/161.txt                                                 26  OK
# Extracting  img/162.jpg                                                 27  OK
# Extracting  img/162.txt                                                 27  OK
# Extracting  img/168.jpg                                                 29  OK
# Extracting  img/168.txt                                                 29  OK
# Extracting  img/17.jpg                                                  30  OK
# Extracting  img/17.txt                                                  30  OK
# Extracting  img/171.jpg                                                 30  OK
# Extracting  img/171.txt                                                 30  OK
# Extracting  img/173.jpg                                                 31  OK
# Extracting  img/173.txt                                                 31  OK
# Extracting  img/176.jpg                                                 32  OK
# Extracting  img/176.txt                                                 32  OK
# Extracting  img/179.jpg                                                 33  OK
# Extracting  img/179.txt                                                 33  OK
# Extracting  img/184.jpg                                                 33  OK
# Extracting  img/184.txt                                                 33  OK
# Extracting  img/188.jpg                                                 33  OK
# Extracting  img/188.txt                                                 33  OK
# Extracting  img/19.jpg                                                  33  OK
# Extracting  img/19.txt                                                  33  OK
# Extracting  img/190.jpg                                                 34  OK
# Extracting  img/190.txt                                                 34  OK
# Extracting  img/191.jpg                                                 34  OK
# Extracting  img/191.txt                                                 34  OK
# Extracting  img/192.jpg                                                 34  OK
# Extracting  img/192.txt                                                 34  OK
# Extracting  img/195.jpg                                                 35  OK
# Extracting  img/195.txt                                                 35  OK
# Extracting  img/2.jpg                                                   36  OK
# Extracting  img/2.txt                                                   36  OK
# Extracting  img/200.jpg                                                 36  OK
# Extracting  img/200.txt                                                 36  OK
# Extracting  img/208.jpg                                                 37  OK
# Extracting  img/208.txt                                                 37  OK
# Extracting  img/209.jpg                                                 37  OK
# Extracting  img/209.txt                                                 37  OK
# Extracting  img/21.jpg                                                  37  OK
# Extracting  img/21.txt                                                  37  OK
# Extracting  img/214.jpg                                                 38  OK
# Extracting  img/214.txt                                                 38  OK
# Extracting  img/215.jpg                                                 38  OK
# Extracting  img/215.txt                                                 38  OK
# Extracting  img/217.jpg                                                 39  OK
# Extracting  img/217.txt                                                 39  OK
# Extracting  img/219.jpg                                                 40  OK
# Extracting  img/219.txt                                                 40  OK
# Extracting  img/22.jpg                                                  40  OK
# Extracting  img/22.txt                                                  40  OK
# Extracting  img/222.jpg                                                 41  OK
# Extracting  img/222.txt                                                 41  OK
# Extracting  img/223.jpg                                                 42  OK
# Extracting  img/223.txt                                                 42  OK
# Extracting  img/225.jpg                                                 42  OK
# Extracting  img/225.txt                                                 42  OK
# Extracting  img/226.jpg                                                 42  OK
# Extracting  img/226.txt                                                 42  OK
# Extracting  img/228.jpg                                                 42  OK
# Extracting  img/228.txt                                                 42  OK
# Extracting  img/233.jpg                                                 43  OK
# Extracting  img/233.txt                                                 43  OK
# Extracting  img/234.jpg                                                 43  OK
# Extracting  img/234.txt                                                 43  OK
# Extracting  img/239.jpg                                                 44  OK
# Extracting  img/239.txt                                                 44  OK
# Extracting  img/240.jpg                                                 44  OK
# Extracting  img/240.txt                                                 44  OK
# Extracting  img/26.jpg                                                  45  OK
# Extracting  img/26.txt                                                  45  OK
# Extracting  img/27.jpg                                                  46  OK
# Extracting  img/27.txt                                                  46  OK
# Extracting  img/28.jpg                                                  47  OK
# Extracting  img/28.txt                                                  47  OK
# Extracting  img/33.jpg                                                  47  OK
# Extracting  img/33.txt                                                  47  OK
# Extracting  img/34.jpg                                                  48  OK
# Extracting  img/34.txt                                                  48  OK
# Extracting  img/35.jpg                                                  48  OK
# Extracting  img/35.txt                                                  48  OK
# Extracting  img/36.jpg                                                  48  OK
# Extracting  img/36.txt                                                  48  OK
# Extracting  img/40.jpg                                                  49  OK
# Extracting  img/40.txt                                                  49  OK
# Extracting  img/41.jpg                                                  49  OK
# Extracting  img/41.txt                                                  49  OK
# Extracting  img/46.jpg                                                  49  OK
# Extracting  img/46.txt                                                  49  OK
# Extracting  img/47.jpg                                                  49  OK
# Extracting  img/47.txt                                                  49  OK
# Extracting  img/48.jpg                                                  50  OK
# Extracting  img/48.txt                                                  50  OK
# Extracting  img/5.jpg                                                   50  OK
# Extracting  img/5.txt                                                   50  OK
# Extracting  img/504.jpg                                                 50  OK
# Extracting  img/504.txt                                                 50  OK
# Extracting  img/505.jpg                                                 50  OK
# Extracting  img/505.txt                                                 50  OK
# Extracting  img/507.jpg                                                 51  OK
# Extracting  img/507.txt                                                 51  OK
# Extracting  img/53.jpg                                                  51  OK
# Extracting  img/53.txt                                                  51  OK
# Extracting  img/54.jpg                                                  51  OK
# Extracting  img/54.txt                                                  51  OK
# Extracting  img/55.jpg                                                  52  OK
# Extracting  img/55.txt                                                  52  OK
# Extracting  img/57.jpg                                                  52  OK
# Extracting  img/57.txt                                                  52  OK
# Extracting  img/6.jpg                                                   52  OK
# Extracting  img/6.txt                                                   52  OK
# Extracting  img/60.jpg                                                  52  OK
# Extracting  img/60.txt                                                  52  OK
# Extracting  img/66.jpg                                                  53  OK
# Extracting  img/66.txt                                                  53  OK
# Extracting  img/68.jpg                                                  54  OK
# Extracting  img/68.txt                                                  54  OK
# Extracting  img/69.jpg                                                  54  OK
# Extracting  img/69.txt                                                  54  OK
# Extracting  img/7.jpg                                                   54  OK
# Extracting  img/7.txt                                                   54  OK
# Extracting  img/71.jpg                                                  55  OK
# Extracting  img/71.txt                                                  55  OK
# Extracting  img/72.jpg                                                  55  OK
# Extracting  img/72.txt                                                  55  OK
# Extracting  img/73.jpg                                                  55  OK
# Extracting  img/73.txt                                                  55  OK
# Extracting  img/76.jpg                                                  55  OK
# Extracting  img/76.txt                                                  55  OK
# Extracting  img/77.jpg                                                  55  OK
# Extracting  img/77.txt                                                  55  OK
# Extracting  img/78.jpg                                                  56  OK
# Extracting  img/78.txt                                                  56  OK
# Extracting  img/79.jpg                                                  56  OK
# Extracting  img/79.txt                                                  56  OK
# Extracting  img/81.jpg                                                  56  OK
# Extracting  img/81.txt                                                  56  OK
# Extracting  img/85.jpg                                                  57  OK
# Extracting  img/85.txt                                                  57  OK
# Extracting  img/88.jpg                                                  57  OK
# Extracting  img/88.txt                                                  57  OK
# Extracting  img/89.jpg                                                  58  OK
# Extracting  img/89.txt                                                  58  OK
# Extracting  img/9.jpg                                                   58  OK
# Extracting  img/9.txt                                                   58  OK
# Extracting  img/95.jpg                                                  59  OK
# Extracting  img/95.txt                                                  59  OK
# Extracting  img/96.jpg                                                  59  OK
# Extracting  img/96.txt                                                  59  OK
# Extracting  img/99.jpg                                                  60  OK
# Extracting  img/99.txt                                                  60  OK
# Creating    img1                                                      OK
# Extracting  img1/cone0208.jpg                                           61  OK
# Extracting  img1/cone0208.txt                                           61  OK
# Extracting  img1/cone0262.jpg                                           62  OK
# Extracting  img1/cone0262.txt                                           62  OK
# Extracting  img1/cone0284.jpg                                           63  OK
# Extracting  img1/cone0284.txt                                           63  OK
# Extracting  img1/cone0306.jpg                                           64  OK
# Extracting  img1/cone0306.txt                                           64  OK
# Extracting  img1/cone0328.jpg                                           65  OK
# Extracting  img1/cone0328.txt                                           65  OK
# Extracting  img1/cone0569.jpg                                           66  OK
# Extracting  img1/cone0569.txt                                           66  OK
# Extracting  img1/cone0580.jpg                                           67  OK
# Extracting  img1/cone0580.txt                                           67  OK
# Extracting  img1/cone0588.jpg                                           68  OK
# Extracting  img1/cone0588.txt                                           68  OK
# Extracting  img1/cone0598.jpg                                           69  OK
# Extracting  img1/cone0598.txt                                           69  OK
# Extracting  img1/cone0610.jpg                                           70  OK
# Extracting  img1/cone0610.txt                                           70  OK
# Extracting  img1/cone0611.jpg                                           71  OK
# Extracting  img1/cone0611.txt                                           71  OK
# Extracting  img1/cone0616.jpg                                           72  OK
# Extracting  img1/cone0616.txt                                           72  OK
# Extracting  img1/cone0619.jpg                                           72  OK
# Extracting  img1/cone0619.txt                                           72  OK
# Extracting  img1/cone0620.jpg                                           73  OK
# Extracting  img1/cone0620.txt                                           73  OK
# Extracting  img1/cone0624.jpg                                           74  OK
# Extracting  img1/cone0624.txt                                           74  OK
# Extracting  img1/cone0625.jpg                                           75  OK
# Extracting  img1/cone0625.txt                                           75  OK
# Extracting  img1/cone1507.jpg                                           76  OK
# Extracting  img1/cone1507.txt                                           76  OK
# Extracting  img1/cone1510.jpg                                           78  OK
# Extracting  img1/cone1510.txt                                           78  OK
# Extracting  img1/cone1511.jpg                                           79  OK
# Extracting  img1/cone1511.txt                                           79  OK
# Extracting  img1/cone1512.jpg                                           80  OK
# Extracting  img1/cone1512.txt                                           80  OK
# Extracting  img1/cone1513.jpg                                           81  OK
# Extracting  img1/cone1513.txt                                           81  OK
# Extracting  img1/cone1514.jpg                                           83  OK
# Extracting  img1/cone1514.txt                                           83  OK
# Extracting  img1/cone1563.jpg                                           84  OK
# Extracting  img1/cone1563.txt                                           84  OK
# Extracting  img1/cone1564.jpg                                           85  OK
# Extracting  img1/cone1564.txt                                           85  OK
# Extracting  img1/cone1690.jpg                                           86  OK
# Extracting  img1/cone1690.txt                                           86  OK
# Extracting  img1/cone1815.jpg                                           88  OK
# Extracting  img1/cone1815.txt                                           88  OK
# Extracting  img1/cone1954.jpg                                           89  OK
# Extracting  img1/cone1954.txt                                           89  OK
# Extracting  img1/cone2102.jpg                                           91  OK
# Extracting  img1/cone2102.txt                                           91  OK
# Extracting  img1/cone2396.jpg                                           92  OK
# Extracting  img1/cone2396.txt                                           92  OK
# Extracting  img1/cone3012.jpg                                           93  OK
# Extracting  img1/cone3012.txt                                           93  OK
# Extracting  img1/cone3040.jpg                                           94  OK
# Extracting  img1/cone3040.txt                                           94  OK
# Extracting  img1/cone3041.jpg                                           94  OK
# Extracting  img1/cone3041.txt                                           94  OK
# Extracting  img1/cone3042.jpg                                           95  OK
# Extracting  img1/cone3042.txt                                           95  OK
# Extracting  img1/cone3043.jpg                                           96  OK
# Extracting  img1/cone3043.txt                                           96  OK
# Extracting  img1/cone3044.jpg                                           97  OK
# Extracting  img1/cone3044.txt                                           97  OK
# Extracting  img1/cone3045.jpg                                           98  OK
# Extracting  img1/cone3045.txt                                           98  OK
# Extracting  img1/cone3046.jpg                                           99  OK
# Extracting  img1/cone3046.txt                                           99  OK
# Extracting  img1/cone3047.jpg                                           99  OK
# Extracting  img1/cone3047.txt                                           99  OK
# All OK
# total 19210
# drwxr-xr-x 8 root root       13 Jun 12 03:59 .
# drwxr-xr-x 8 root root        8 Jun 12 03:18 ..
# drwxr-xr-x 2 root root        4 Jun 12 03:58 .ipynb_checkpoints
# drwxr-xr-x 2 root root        5 Jun 12 03:39 __pycache__
# -rw-r--r-- 1 root root    11984 Jun 12 03:30 coco_eval.py
# -rw-r--r-- 1 root root     8732 Jun 12 03:30 coco_utils.py
# -rw-r--r-- 1 root root 19601397 Jun 12 03:58 data.rar
# -rw-r--r-- 1 root root     3746 Jun 12 03:30 engine.py
# drwxr-xr-x 2 root root      245 May 29  2018 img
# drwxr-xr-x 2 root root       76 May  9  2018 img1
# -rw-r--r-- 1 root root    33041 Jun 12 03:42 pytorch.obj.det.youtube.FTA_DUCSS-dg2.ipynb
# -rw-r--r-- 1 root root     1534 Jun 12 03:30 transforms.py
# -rw-r--r-- 1 root root     9161 Jun 12 03:30 utils.py
# drwxr-xr-x 2 root root       20 May 29  2018 v-img
# drwxr-xr-x 7 root root       16 Jun 12 03:30 vision
# /notebooks/ml635e2/635h

# %%
    awidth = 2
    print ('w=', width)
# Out:
# w= 2

# %%
# defining the files directory and testing directory
files_dir = './ir3/train/'
test_dir = './ir3/test/'

# we create a Dataset class which has a __getitem__ function and a __len__ function
class ConeImagesDataset(torch.utils.data.Dataset):

  def __init__(self, files_dir, width, height, transforms=None):
    self.transforms = transforms
    self.files_dir = files_dir
    self.height = height
    self.width = width
    print ('w=',width,'h=',height)
    
    # sorting the images for consistency
    # To get images, the extension of the filename is checked to be jpg
    self.imgs = [image for image in sorted(os.listdir(files_dir)) if image[-4:]=='.jpg']
    
    # classes: 0 index is reserved for background
    self.classes = [_, 'Chip']

  def __getitem__(self, idx):
    img_name = self.imgs[idx]
    image_path = os.path.join(self.files_dir, img_name)

    # reading the images and converting them to correct size and color    
    img = cv2.imread(image_path)
    #img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB).astype(np.float32)
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY).astype(np.float32)
    img_res = cv2.resize(img_rgb, (self.width, self.height), cv2.INTER_AREA)
    # diving by 255
    img_res /= 255.0
    
    # annotation file
    annot_filename = img_name[:-4] + '.txt'
    annot_file_path = os.path.join(self.files_dir, annot_filename)
    
    boxes = []
    labels = []
    
    # cv2 image gives size as height x width
    wt = img.shape[1]
    ht = img.shape[0]
    
    # box coordinates for xml files are extracted and corrected for image size given
    with open(annot_file_path) as f:
      for line in f:
        labels.append(1)
        
        parsed = [float(x) for x in line.split(' ')]
        x_center = parsed[1]
        y_center = parsed[2]
        box_wt = parsed[3]
        box_ht = parsed[4]

        xmin = x_center - box_wt/2
        xmax = x_center + box_wt/2
        ymin = y_center - box_ht/2
        ymax = y_center + box_ht/2
        
        xmin_corr = int(xmin*self.width)
        xmax_corr = int(xmax*self.width)
        ymin_corr = int(ymin*self.height)
        ymax_corr = int(ymax*self.height)
        
        boxes.append([xmin_corr, ymin_corr, xmax_corr, ymax_corr])
    
    # convert boxes into a torch.Tensor
    boxes = torch.as_tensor(boxes, dtype=torch.float32)
    
    # getting the areas of the boxes
    area = (boxes[:, 3] - boxes[:, 1]) * (boxes[:, 2] - boxes[:, 0])

    # suppose all instances are not crowd
    iscrowd = torch.zeros((boxes.shape[0],), dtype=torch.int64)
    
    labels = torch.as_tensor(labels, dtype=torch.int64)

    target = {}
    target["boxes"] = boxes
    target["labels"] = labels
    target["area"] = area
    target["iscrowd"] = iscrowd
    image_id = torch.tensor([idx])
    target["image_id"] = image_id

    if self.transforms:
      sample = self.transforms(image = img_res,
                                bboxes = target['boxes'],
                                labels = labels)
      img_res = sample['image']
      target['boxes'] = torch.Tensor(sample['bboxes'])
        
    return img_res, target

  def __len__(self):
    return len(self.imgs)


# check dataset
dataset = ConeImagesDataset(files_dir, 260, 7990)
print('Length of dataset:', len(dataset), '\n')

# getting the image and target for a test index.  Feel free to change the index.
img, target = dataset[0]
print('Image shape:', img.shape)
print('Label example:', target)
# Out:
# w= 260 h= 7990
# Length of dataset: 4
#
# Image shape: (7990, 260)
# Label example: {'boxes': tensor([[   0., 6731.,  183., 6945.]]), 'labels': tensor([1]), 'area': tensor([39162.]), 'iscrowd': tensor([0]), 'image_id': tensor([0])}

# %% [markdown]
# # Visualization
#
# Let's make some a helper function to view our data

# %%
# Function to visualize bounding boxes in the image
def plot_img_bbox(img, target):
  # plot the image and bboxes
  # Bounding boxes are defined as follows: x-min y-min width height
  fig, a = plt.subplots(1,1)
  fig.set_size_inches(11,22)
  a.imshow(img)
  for box in (target['boxes']):
    x, y, width, height  = box[0], box[1], box[2]-box[0], box[3]-box[1]
    rect = patches.Rectangle(
      (x, y),
      width, height,
      linewidth = 2,
      edgecolor = 'r',
      facecolor = 'none'
    )
    # Draw the bounding box on top of the image
    a.add_patch(rect)
  plt.show()
    
# plotting the image with bboxes. Feel free to change the index
img, target = dataset[0]
plot_img_bbox(img, target)

# %% [markdown]
# # Augmentations

# %% [markdown]
# This is where we can apply augmentations to the image.
#
# The augmentations to object detection vary from normal augmentations becuase here we need to ensure that, bbox still aligns with the object correctly after transforming.
#
# Here we are doing a random flip transform.

# %%
# Send train=True for training transforms and False for val/test transforms
def get_transform(train):
  if train:
    return A.Compose(
      [
        A.HorizontalFlip(0.5),
        # ToTensorV2 converts image to pytorch tensor without div by 255
        ToTensorV2(p=1.0) 
      ],
      bbox_params={'format': 'pascal_voc', 'label_fields': ['labels']}
    )
  else:
    return A.Compose(
      [ToTensorV2(p=1.0)],
      bbox_params={'format': 'pascal_voc', 'label_fields': ['labels']}
    )

# %% [markdown]
# # Dataloaders
#
# Make a loader for feeding our data into the neural network

# %% [markdown]
# Now lets prepare the datasets and dataloaders for training and testing.

# %%
# use our dataset and defined transformations
dataset = ConeImagesDataset(files_dir, 260, 7990, transforms=get_transform(train=True))
dataset_test = ConeImagesDataset(files_dir, 260, 7990, transforms=get_transform(train=False))

# split the dataset in train and test set
torch.manual_seed(1)
indices = torch.randperm(len(dataset)).tolist()

# train test split
test_split = 0.25
tsize = int(len(dataset)*test_split)
dataset = torch.utils.data.Subset(dataset, indices[:-tsize])
dataset_test = torch.utils.data.Subset(dataset_test, indices[-tsize:])

# define training and validation data loaders
data_loader = torch.utils.data.DataLoader(
  dataset,
  batch_size=10,
  shuffle=True,
  num_workers=4,
  collate_fn=utils.collate_fn,
)

data_loader_test = torch.utils.data.DataLoader(
  dataset_test,
  batch_size=10,
  shuffle=False,
  num_workers=4,
  collate_fn=utils.collate_fn,
)
# Out:
# w= 260 h= 7990
# w= 260 h= 7990

# %% [markdown]
# # Pre-trained Model

# %%
def get_object_detection_model(num_classes):
  # load a model pre-trained pre-trained on COCO
  model = torchvision.models.detection.fasterrcnn_resnet50_fpn(pretrained=True)
  # get number of input features for the classifier
  in_features = model.roi_heads.box_predictor.cls_score.in_features
  # replace the pre-trained head with a new one
  model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes) 
  return model

# %% [markdown]
# # Training

# %% [markdown]
# Let's prepare the model for training

# %%
# train on gpu if available
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
print(device)

num_classes = 2 # one class (class 0) is dedicated to the "background"

# get the model using our helper function
model = get_object_detection_model(num_classes)

# move model to the right device
model.to(device)

# construct an optimizer
params = [p for p in model.parameters() if p.requires_grad]
optimizer = torch.optim.SGD(params, lr=0.005, momentum=0.9, weight_decay=0.0005)

# and a learning rate scheduler which decreases the learning rate by
# 10x every 3 epochs
lr_scheduler = torch.optim.lr_scheduler.StepLR(
  optimizer,
  step_size=3,
  gamma=0.1
)
# !pwd
# Out:
# cuda
# /notebooks/ml635e2/ml635h

# %% [markdown]
# Let the training begin!

# %%
# training for 5 epochs
num_epochs = 5

for epoch in range(num_epochs):
    # training for one epoch
    train_one_epoch(model, optimizer, data_loader, device, epoch, print_freq=10)
    # update the learning rate
    lr_scheduler.step()
    # evaluate on the test dataset
    evaluate(model, data_loader_test, device=device)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_301/3743040114.py in <module>
#       4 for epoch in range(num_epochs):
#       5     # training for one epoch
# ----> 6     train_one_epoch(model, optimizer, data_loader, device, epoch, print_freq=10)
#       7     # update the learning rate
#       8     lr_scheduler.step()
#
# /notebooks/ml635e2/ml635h/engine.py in train_one_epoch(model, optimizer, data_loader, device, epoch, print_freq)
#      24         lr_scheduler = utils.warmup_lr_scheduler(optimizer, warmup_iters, warmup_factor)
#      25
# ---> 26     for images, targets in metric_logger.log_every(data_loader, print_freq, header):
#      27         images = list(image.to(device) for image in images)
#      28         targets = [{k: v.to(device) for k, v in t.items()} for t in targets]
#
# /notebooks/ml635e2/ml635h/utils.py in log_every(self, iterable, print_freq, header)
#     199         ])
#     200         MB = 1024.0 * 1024.0
# --> 201         for obj in iterable:
#     202             data_time.update(time.time() - end)
#     203             yield obj
#
# /opt/conda/lib/python3.7/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     519             if self._sampler_iter is None:
#     520                 self._reset()
# --> 521             data = self._next_data()
#     522             self._num_yielded += 1
#     523             if self._dataset_kind == _DatasetKind.Iterable and \
#
# /opt/conda/lib/python3.7/site-packages/torch/utils/data/dataloader.py in _next_data(self)
#    1201             else:
#    1202                 del self._task_info[idx]
# -> 1203                 return self._process_data(data)
#    1204
#    1205     def _try_put_index(self):
#
# /opt/conda/lib/python3.7/site-packages/torch/utils/data/dataloader.py in _process_data(self, data)
#    1227         self._try_put_index()
#    1228         if isinstance(data, ExceptionWrapper):
# -> 1229             data.reraise()
#    1230         return data
#    1231
#
# /opt/conda/lib/python3.7/site-packages/torch/_utils.py in reraise(self)
#     432             # instantiate since we don't know how to
#     433             raise RuntimeError(msg) from None
# --> 434         raise exception
#     435
#     436
#
# ValueError: Caught ValueError in DataLoader worker process 0.
# Original Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/torch/utils/data/_utils/worker.py", line 287, in _worker_loop
#     data = fetcher.fetch(index)
#   File "/opt/conda/lib/python3.7/site-packages/torch/utils/data/_utils/fetch.py", line 49, in fetch
#     data = [self.dataset[idx] for idx in possibly_batched_index]
#   File "/opt/conda/lib/python3.7/site-packages/torch/utils/data/_utils/fetch.py", line 49, in <listcomp>
#     data = [self.dataset[idx] for idx in possibly_batched_index]
#   File "/opt/conda/lib/python3.7/site-packages/torch/utils/data/dataset.py", line 363, in __getitem__
#     return self.dataset[self.indices[idx]]
#   File "/tmp/ipykernel_301/3105659504.py", line 90, in __getitem__
#     labels = labels)
#   File "/opt/conda/lib/python3.7/site-packages/albumentations/core/composition.py", line 176, in __call__
#     data = t(force_apply=force_apply, **data)
#   File "/opt/conda/lib/python3.7/site-packages/albumentations/core/transforms_interface.py", line 87, in __call__
#     return self.apply_with_params(params, **kwargs)
#   File "/opt/conda/lib/python3.7/site-packages/albumentations/core/transforms_interface.py", line 100, in apply_with_params
#     res[key] = target_function(arg, **dict(params, **target_dependencies))
#   File "/opt/conda/lib/python3.7/site-packages/albumentations/pytorch/transforms.py", line 92, in apply
#     return torch.from_numpy(img.transpose(2, 0, 1))
# ValueError: axes don't match array

# %% [markdown]
# # Filtering the outputs

# %% [markdown]
# Our model predicts a lot of bounding boxes per image, so take out the overlapping ones, we will use **Non Max Suppression** (NMS). If you want to brush up on that, check [this](https://towardsdatascience.com/non-maximum-suppression-nms-93ce178e177c) out.
#
# Torchvision provides us a utility to apply NMS to our predictions, lets build a function `apply_nms` using that.

# %%
# the function takes the original prediction and the iou threshold.
def apply_nms(orig_prediction, iou_thresh=0.3):
  # torchvision returns the indices of the bboxes to keep
  keep = torchvision.ops.nms(orig_prediction['boxes'], orig_prediction['scores'], iou_thresh)
  
  final_prediction = orig_prediction
  final_prediction['boxes'] = final_prediction['boxes'][keep]
  final_prediction['scores'] = final_prediction['scores'][keep]
  final_prediction['labels'] = final_prediction['labels'][keep]
  
  return final_prediction

# function to convert a torchtensor back to PIL image
def torch_to_pil(img):
  return torchtrans.ToPILImage()(img).convert('RGB')

# %% [markdown]
# # Testing our Model

# %% [markdown]
# Now lets take an image from the test set and try to predict on it

# %%
test_dataset = ConeImagesDataset(test_dir, 480, 480, transforms= get_transform(train=True))

# pick one image from the test set
img, target = test_dataset[10]
# put the model in evaluation mode
model.eval()
with torch.no_grad():
  prediction = model([img.to(device)])[0]
    
print('MODEL OUTPUT\n')
nms_prediction = apply_nms(prediction, iou_thresh=0.01)

plot_img_bbox(torch_to_pil(img), nms_prediction)
# Out:
# MODEL OUTPUT
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_105/3270506572.py in <module>
#      11 nms_prediction = apply_nms(prediction, iou_thresh=0.01)
#      12
# ---> 13 plot_img_bbox(torch_to_pil(img), nms_prediction)
#
# /tmp/ipykernel_105/4277478199.py in plot_img_bbox(img, target)
#      16     )
#      17     # Draw the bounding box on top of the image
# ---> 18     a.add_patch(rect)
#      19   plt.show()
#      20
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/axes/_base.py in add_patch(self, p)
#    2168         if p.get_clip_path() is None:
#    2169             p.set_clip_path(self.patch)
# -> 2170         self._update_patch_limits(p)
#    2171         self.patches.append(p)
#    2172         p._remove_method = self.patches.remove
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/axes/_base.py in _update_patch_limits(self, patch)
#    2190             p.codes, (mpath.Path.CLOSEPOLY, mpath.Path.STOP), invert=True)]
#    2191         if vertices.size > 0:
# -> 2192             xys = patch.get_patch_transform().transform(vertices)
#    2193             if patch.get_data_transform() != self.transData:
#    2194                 patch_to_data = (patch.get_data_transform() -
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/patches.py in get_patch_transform(self)
#     775         # important to call the accessor method and not directly access the
#     776         # transformation member variable.
# --> 777         bbox = self.get_bbox()
#     778         return (transforms.BboxTransformTo(bbox)
#     779                 + transforms.Affine2D().rotate_deg_around(
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/patches.py in get_bbox(self)
#     855         """Return the `.Bbox`."""
#     856         x0, y0, x1, y1 = self._convert_units()
# --> 857         return transforms.Bbox.from_extents(x0, y0, x1, y1)
#     858
#     859     xy = property(get_xy, set_xy)
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/transforms.py in from_extents(minpos, *args)
#     844            scales where negative bounds result in floating point errors.
#     845         """
# --> 846         bbox = Bbox(np.reshape(args, (2, 2)))
#     847         if minpos is not None:
#     848             bbox._minpos[:] = minpos
#
# <__array_function__ internals> in reshape(*args, **kwargs)
#
# /opt/conda/lib/python3.7/site-packages/numpy/core/fromnumeric.py in reshape(a, newshape, order)
#     296            [5, 6]])
#     297     """
# --> 298     return _wrapfunc(a, 'reshape', newshape, order=order)
#     299
#     300
#
# /opt/conda/lib/python3.7/site-packages/numpy/core/fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      52     bound = getattr(obj, method, None)
#      53     if bound is None:
# ---> 54         return _wrapit(obj, method, *args, **kwds)
#      55
#      56     try:
#
# /opt/conda/lib/python3.7/site-packages/numpy/core/fromnumeric.py in _wrapit(obj, method, *args, **kwds)
#      41     except AttributeError:
#      42         wrap = None
# ---> 43     result = getattr(asarray(obj), method)(*args, **kwds)
#      44     if wrap:
#      45         if not isinstance(result, mu.ndarray):
#
# /opt/conda/lib/python3.7/site-packages/torch/_tensor.py in __array__(self, dtype)
#     676             return handle_torch_function(Tensor.__array__, (self,), self, dtype=dtype)
#     677         if dtype is None:
# --> 678             return self.numpy()
#     679         else:
#     680             return self.numpy().astype(dtype, copy=False)
#
# TypeError: can't convert cuda:0 device type tensor to numpy. Use Tensor.cpu() to copy the tensor to host memory first.

# %%
torch.save(model, './outmodel.pth')

# %%
torch.save(model.state_dict(), './outmodelstate.pth')
