# %% [markdown]
# # **FINE TUNING FASTER RCNN USING PYTORCH**
#
# 6 os
#
# In this Notebook we can fine tune a Faster RCNN on the images dataset. If you want to brush up about what is Faster RCNN, [here's](https://medium.com/@whatdhack/a-deeper-look-at-how-faster-rcnn-works-84081284e1cd) an awesome medium article on the same.
#
# Ref: inspired by the Pytorch docs tutorial [here](https://pytorch.org/tutorials/intermediate/torchvision_tutorial.html)

# %% [markdown]
# ## Installs and Imports

# %% [markdown]
# Since a lot of code for object detection is same and has to be rewritten by everyone, torchvision contributers have provided us with helper codes for training, evaluation and transformations.
#
# Let's clone the repo and copy the libraries into working directory

# %%
# Download TorchVision repo to use some files from references/detection
# !git clone https://github.com/pytorch/vision.git
# !git checkout v0.3.0
# !cp vision/references/detection/utils.py ./
# !cp vision/references/detection/transforms.py ./
# !cp vision/references/detection/coco_eval.py ./
# !cp vision/references/detection/engine.py ./
# !cp vision/references/detection/coco_utils.py ./

# %%
# %%bash
# apt update
# DEBIAN_FRONTEND=noninteractive apt-get install -y python3-opencv
# #tz prompt. dpkg fix...
# pip install opencv-python
# #pip install cv2

# %%
# !pip install pycocotools

# %%
pip list
# Out:
# Package                 Version
# ----------------------- ---------
# absl-py                 1.0.0
# albumentations          1.1.0
# argcomplete             1.12.3
# argon2-cffi             21.1.0
# attrs                   21.2.0
# backcall                0.2.0
# beautifulsoup4          4.10.0
# bleach                  4.1.0
# blis                    0.7.5
# boto3                   1.20.4
# botocore                1.23.4
# bravado                 11.0.3
# bravado-core            5.17.0
# brotlipy                0.7.0
# cachetools              4.2.4
# captum                  0.4.1
# catalogue               2.0.6
# catalyst                21.10
# certifi                 2021.10.8
# cffi                    1.14.6
# chardet                 4.0.0
# click                   8.0.3
# conda                   4.10.3
# conda-build             3.21.5
# conda-package-handling  1.7.3
# configparser            5.1.0
# cryptography            3.4.8
# cycler                  0.11.0
# cymem                   2.0.6
# debugpy                 1.5.1
# decorator               5.1.0
# defusedxml              0.7.1
# dnspython               2.1.0
# docker-pycreds          0.4.0
# entrypoints             0.3
# fastai                  2.5.4
# fastcore                1.3.28
# fastdownload            0.0.5
# fastprogress            1.0.0
# fastrelease             0.1.12
# filelock                3.0.12
# future                  0.18.2
# ghapi                   0.1.19
# gitdb                   4.0.9
# GitPython               3.1.24
# glob2                   0.7
# google-auth             2.3.3
# google-auth-oauthlib    0.4.6
# graphviz                0.18
# grpcio                  1.41.1
# hydra-slayer            0.3.0
# idna                    2.10
# imageio                 2.10.3
# importlib-metadata      4.8.2
# ipykernel               6.5.0
# ipython                 7.27.0
# ipython-genutils        0.2.0
# ipywidgets              7.6.5
# jedi                    0.18.0
# Jinja2                  2.11.3
# jmespath                0.10.0
# joblib                  1.1.0
# jsonpointer             2.2
# jsonref                 0.2
# jsonschema              3.2.0
# jupyter                 1.0.0
# jupyter-client          6.1.12
# jupyter-console         6.4.0
# jupyter-core            4.9.1
# jupyterlab-widgets      1.0.2
# kiwisolver              1.3.2
# kornia                  0.6.1
# langcodes               3.3.0
# libarchive-c            2.9
# Markdown                3.3.4
# MarkupSafe              2.0.1
# matplotlib              3.4.3
# matplotlib-inline       0.1.2
# mistune                 0.8.4
# mkl-fft                 1.3.1
# mkl-random              1.2.2
# mkl-service             2.4.0
# monotonic               1.6
# msgpack                 1.0.2
# murmurhash              1.0.6
# nbconvert               5.6.1
# nbdev                   1.1.23
# nbformat                5.1.3
# neptune-client          0.13.1
# networkx                2.6.3
# notebook                6.4.5
# numpy                   1.21.2
# oauthlib                3.1.1
# olefile                 0.46
# opencv-python           4.5.4.58
# opencv-python-headless  4.5.4.58
# packaging               21.2
# pandas                  1.3.4
# pandocfilters           1.5.0
# parso                   0.8.2
# pathtools               0.1.2
# pathy                   0.6.1
# pexpect                 4.8.0
# pickleshare             0.7.5
# Pillow                  8.4.0
# pip                     21.0.1
# pkginfo                 1.7.1
# preshed                 3.0.6
# prometheus-client       0.12.0
# promise                 2.3
# prompt-toolkit          3.0.20
# protobuf                3.19.1
# psutil                  5.8.0
# ptyprocess              0.7.0
# pyarrow                 6.0.0
# pyasn1                  0.4.8
# pyasn1-modules          0.2.8
# pycocotools             2.0.4
# pycosat                 0.6.3
# pycparser               2.20
# pydantic                1.8.2
# pydicom                 2.2.2
# Pygments                2.10.0
# PyJWT                   2.3.0
# pyOpenSSL               20.0.1
# pyparsing               2.4.7
# pyrsistent              0.18.0
# PySocks                 1.7.1
# python-dateutil         2.8.2
# python-etcd             0.4.5
# pytz                    2021.3
# PyWavelets              1.2.0
# PyYAML                  5.4.1
# pyzmq                   22.3.0
# qtconsole               5.2.0
# QtPy                    1.11.2
# qudida                  0.0.4
# requests                2.25.1
# requests-oauthlib       1.3.0
# rfc3987                 1.3.8
# rsa                     4.7.2
# ruamel-yaml-conda       0.15.100
# s3transfer              0.5.0
# scikit-image            0.18.3
# scikit-learn            1.0.1
# scipy                   1.7.2
# Send2Trash              1.8.0
# sentencepiece           0.1.86
# sentry-sdk              1.4.3
# setuptools              58.0.4
# shortuuid               1.0.8
# simplejson              3.17.5
# six                     1.16.0
# smart-open              5.2.1
# smmap                   5.0.0
# soupsieve               2.2.1
# spacy                   3.2.0
# spacy-legacy            3.0.8
# spacy-loggers           1.0.1
# srsly                   2.4.2
# strict-rfc3339          0.7
# subprocess32            3.5.4
# swagger-spec-validator  2.7.4
# tensorboard             2.7.0
# tensorboard-data-server 0.6.1
# tensorboard-plugin-wit  1.8.0
# tensorboardX            2.2
# termcolor               1.1.0
# terminado               0.12.1
# testpath                0.5.0
# thinc                   8.0.13
# threadpoolctl           3.0.0
# tifffile                2021.11.2
# torch                   1.10.0
# torchelastic            0.2.0
# torchtext               0.11.0
# torchvision             0.11.0
# tornado                 6.1
# tqdm                    4.61.2
# traitlets               5.1.0
# typer                   0.4.0
# typing-extensions       3.10.0.2
# urllib3                 1.26.6
# wandb                   0.12.6
# wasabi                  0.8.2
# wcwidth                 0.2.5
# webcolors               1.11.1
# webencodings            0.5.1
# websocket-client        1.2.1
# Werkzeug                2.0.2
# wheel                   0.36.2
# widgetsnbextension      3.5.2
# yaspin                  2.1.0
# zipp                    3.6.0
# Note: you may need to restart the kernel to use updated packages.

# %%
conda list
# Out:
# # packages in environment at /opt/conda:
# #
# # Name                    Version                   Build  Channel
# _libgcc_mutex             0.1                        main
# _openmp_mutex             4.5                       1_gnu
# absl-py                   1.0.0                    pypi_0    pypi
# albumentations            1.1.0                    pypi_0    pypi
# argcomplete               1.12.3                   pypi_0    pypi
# argon2-cffi               21.1.0                   pypi_0    pypi
# attrs                     21.2.0                   pypi_0    pypi
# backcall                  0.2.0              pyhd3eb1b0_0
# beautifulsoup4            4.10.0             pyh06a4308_0
# blas                      1.0                         mkl
# bleach                    4.1.0                    pypi_0    pypi
# blis                      0.7.5                    pypi_0    pypi
# boto3                     1.20.4                   pypi_0    pypi
# botocore                  1.23.4                   pypi_0    pypi
# bravado                   11.0.3                   pypi_0    pypi
# bravado-core              5.17.0                   pypi_0    pypi
# brotlipy                  0.7.0           py37h27cfd23_1003
# bzip2                     1.0.8                h7b6447c_0
# ca-certificates           2021.9.30            h06a4308_1
# cachetools                4.2.4                    pypi_0    pypi
# captum                    0.4.1                    pypi_0    pypi
# catalogue                 2.0.6                    pypi_0    pypi
# catalyst                  21.10                    pypi_0    pypi
# certifi                   2021.10.8        py37h06a4308_0
# cffi                      1.14.6           py37h400218f_0
# chardet                   4.0.0           py37h06a4308_1003
# click                     8.0.3                    pypi_0    pypi
# conda                     4.10.3           py37h06a4308_0
# conda-build               3.21.5           py37h06a4308_0
# conda-package-handling    1.7.3            py37h27cfd23_1
# configparser              5.1.0                    pypi_0    pypi
# cryptography              3.4.8            py37hd23ed53_0
# cudatoolkit               11.3.1               ha36c431_9    nvidia
# cycler                    0.11.0                   pypi_0    pypi
# cymem                     2.0.6                    pypi_0    pypi
# debugpy                   1.5.1                    pypi_0    pypi
# decorator                 5.1.0              pyhd3eb1b0_0
# defusedxml                0.7.1                    pypi_0    pypi
# dnspython                 2.1.0                    pypi_0    pypi
# docker-pycreds            0.4.0                    pypi_0    pypi
# entrypoints               0.3                      pypi_0    pypi
# fastai                    2.5.4                    pypi_0    pypi
# fastcore                  1.3.28                   pypi_0    pypi
# fastdownload              0.0.5                    pypi_0    pypi
# fastprogress              1.0.0                    pypi_0    pypi
# fastrelease               0.1.12                   pypi_0    pypi
# ffmpeg                    4.3                  hf484d3e_0    pytorch
# filelock                  3.0.12             pyhd3eb1b0_1
# freetype                  2.10.4               h5ab3b9f_0
# future                    0.18.2                   pypi_0    pypi
# ghapi                     0.1.19                   pypi_0    pypi
# giflib                    5.2.1                h7b6447c_0
# gitdb                     4.0.9                    pypi_0    pypi
# gitpython                 3.1.24                   pypi_0    pypi
# glob2                     0.7                pyhd3eb1b0_0
# gmp                       6.2.1                h2531618_2
# gnutls                    3.6.15               he1e5248_0
# google-auth               2.3.3                    pypi_0    pypi
# google-auth-oauthlib      0.4.6                    pypi_0    pypi
# grpcio                    1.41.1                   pypi_0    pypi
# hydra-slayer              0.3.0                    pypi_0    pypi
# icu                       58.2                 he6710b0_3
# idna                      2.10               pyhd3eb1b0_0
# imageio                   2.10.3                   pypi_0    pypi
# importlib-metadata        4.8.2                    pypi_0    pypi
# intel-openmp              2021.3.0          h06a4308_3350
# ipykernel                 6.5.0                    pypi_0    pypi
# ipython                   7.27.0           py37hb070fc8_0
# ipython-genutils          0.2.0                    pypi_0    pypi
# ipywidgets                7.6.5                    pypi_0    pypi
# jedi                      0.18.0           py37h06a4308_1
# jinja2                    2.11.3             pyhd3eb1b0_0
# jmespath                  0.10.0                   pypi_0    pypi
# joblib                    1.1.0                    pypi_0    pypi
# jpeg                      9d                   h7f8727e_0
# jsonpointer               2.2                      pypi_0    pypi
# jsonref                   0.2                      pypi_0    pypi
# jsonschema                3.2.0                    pypi_0    pypi
# jupyter                   1.0.0                    pypi_0    pypi
# jupyter-client            6.1.12                   pypi_0    pypi
# jupyter-console           6.4.0                    pypi_0    pypi
# jupyter-core              4.9.1                    pypi_0    pypi
# jupyterlab-widgets        1.0.2                    pypi_0    pypi
# kiwisolver                1.3.2                    pypi_0    pypi
# kornia                    0.6.1                    pypi_0    pypi
# lame                      3.100                h7b6447c_0
# langcodes                 3.3.0                    pypi_0    pypi
# lcms2                     2.12                 h3be6417_0
# ld_impl_linux-64          2.35.1               h7274673_9
# libarchive                3.4.2                h62408e4_0
# libffi                    3.3                  he6710b0_2
# libgcc-ng                 9.3.0               h5101ec6_17
# libgomp                   9.3.0               h5101ec6_17
# libiconv                  1.15                 h63c8f33_5
# libidn2                   2.3.2                h7f8727e_0
# liblief                   0.10.1               he6710b0_0
# libpng                    1.6.37               hbc83047_0
# libstdcxx-ng              9.3.0               hd4cf53a_17
# libtasn1                  4.16.0               h27cfd23_0
# libtiff                   4.2.0                h85742a9_0
# libunistring              0.9.10               h27cfd23_0
# libuv                     1.40.0               h7b6447c_0
# libwebp                   1.2.0                h89dd481_0
# libwebp-base              1.2.0                h27cfd23_0
# libxml2                   2.9.12               h03d6c58_0
# lz4-c                     1.9.3                h295c915_1
# markdown                  3.3.4                    pypi_0    pypi
# markupsafe                2.0.1            py37h27cfd23_0
# matplotlib                3.4.3                    pypi_0    pypi
# matplotlib-inline         0.1.2              pyhd3eb1b0_2
# mistune                   0.8.4                    pypi_0    pypi
# mkl                       2021.3.0           h06a4308_520
# mkl-service               2.4.0            py37h7f8727e_0
# mkl_fft                   1.3.1            py37hd3c417c_0
# mkl_random                1.2.2            py37h51133e4_0
# monotonic                 1.6                      pypi_0    pypi
# msgpack                   1.0.2                    pypi_0    pypi
# murmurhash                1.0.6                    pypi_0    pypi
# nbconvert                 5.6.1                    pypi_0    pypi
# nbdev                     1.1.23                   pypi_0    pypi
# nbformat                  5.1.3                    pypi_0    pypi
# ncurses                   6.2                  he6710b0_1
# neptune-client            0.13.1                   pypi_0    pypi
# nettle                    3.7.3                hbbd107a_1
# networkx                  2.6.3                    pypi_0    pypi
# notebook                  6.4.5                    pypi_0    pypi
# numpy                     1.21.2           py37h20f2e39_0
# numpy-base                1.21.2           py37h79a1101_0
# oauthlib                  3.1.1                    pypi_0    pypi
# olefile                   0.46                     py37_0
# opencv-python             4.5.4.58                 pypi_0    pypi
# opencv-python-headless    4.5.4.58                 pypi_0    pypi
# openh264                  2.1.0                hd408876_0
# openssl                   1.1.1l               h7f8727e_0
# packaging                 21.2                     pypi_0    pypi
# pandas                    1.3.4                    pypi_0    pypi
# pandocfilters             1.5.0                    pypi_0    pypi
# parso                     0.8.2              pyhd3eb1b0_0
# patchelf                  0.13                 h295c915_0
# pathtools                 0.1.2                    pypi_0    pypi
# pathy                     0.6.1                    pypi_0    pypi
# pexpect                   4.8.0              pyhd3eb1b0_3
# pickleshare               0.7.5           pyhd3eb1b0_1003
# pillow                    8.4.0            py37h5aabda8_0
# pip                       21.0.1           py37h06a4308_0
# pkginfo                   1.7.1            py37h06a4308_0
# preshed                   3.0.6                    pypi_0    pypi
# prometheus-client         0.12.0                   pypi_0    pypi
# promise                   2.3                      pypi_0    pypi
# prompt-toolkit            3.0.20             pyhd3eb1b0_0
# protobuf                  3.19.1                   pypi_0    pypi
# psutil                    5.8.0            py37h27cfd23_1
# ptyprocess                0.7.0              pyhd3eb1b0_2
# py-lief                   0.10.1           py37h403a769_0
# pyarrow                   6.0.0                    pypi_0    pypi
# pyasn1                    0.4.8                    pypi_0    pypi
# pyasn1-modules            0.2.8                    pypi_0    pypi
# pycocotools               2.0.4                    pypi_0    pypi
# pycosat                   0.6.3            py37h27cfd23_0
# pycparser                 2.20                       py_2
# pydantic                  1.8.2                    pypi_0    pypi
# pydicom                   2.2.2                    pypi_0    pypi
# pygments                  2.10.0             pyhd3eb1b0_0
# pyjwt                     2.3.0                    pypi_0    pypi
# pyopenssl                 20.0.1             pyhd3eb1b0_1
# pyparsing                 2.4.7                    pypi_0    pypi
# pyrsistent                0.18.0                   pypi_0    pypi
# pysocks                   1.7.1                    py37_1
# python                    3.7.11               h12debd9_0
# python-dateutil           2.8.2                    pypi_0    pypi
# python-etcd               0.4.5                    pypi_0    pypi
# python-graphviz           0.18                     pypi_0    pypi
# python-libarchive-c       2.9                pyhd3eb1b0_1
# pytorch                   1.10.0          py3.7_cuda11.3_cudnn8.2.0_0    pytorch
# pytorch-mutex             1.0                        cuda    pytorch
# pytz                      2021.3             pyhd3eb1b0_0
# pywavelets                1.2.0                    pypi_0    pypi
# pyyaml                    5.4.1            py37h27cfd23_1
# pyzmq                     22.3.0                   pypi_0    pypi
# qtconsole                 5.2.0                    pypi_0    pypi
# qtpy                      1.11.2                   pypi_0    pypi
# qudida                    0.0.4                    pypi_0    pypi
# readline                  8.1                  h27cfd23_0
# requests                  2.25.1             pyhd3eb1b0_0
# requests-oauthlib         1.3.0                    pypi_0    pypi
# rfc3987                   1.3.8                    pypi_0    pypi
# ripgrep                   12.1.1                        0
# rsa                       4.7.2                    pypi_0    pypi
# ruamel_yaml               0.15.100         py37h27cfd23_0
# s3transfer                0.5.0                    pypi_0    pypi
# scikit-image              0.18.3                   pypi_0    pypi
# scikit-learn              1.0.1                    pypi_0    pypi
# scipy                     1.7.2                    pypi_0    pypi
# send2trash                1.8.0                    pypi_0    pypi
# sentencepiece             0.1.86                   pypi_0    pypi
# sentry-sdk                1.4.3                    pypi_0    pypi
# setuptools                58.0.4           py37h06a4308_0
# shortuuid                 1.0.8                    pypi_0    pypi
# simplejson                3.17.5                   pypi_0    pypi
# six                       1.16.0             pyhd3eb1b0_0
# smart-open                5.2.1                    pypi_0    pypi
# smmap                     5.0.0                    pypi_0    pypi
# soupsieve                 2.2.1              pyhd3eb1b0_0
# spacy                     3.2.0                    pypi_0    pypi
# spacy-legacy              3.0.8                    pypi_0    pypi
# spacy-loggers             1.0.1                    pypi_0    pypi
# sqlite                    3.36.0               hc218d9a_0
# srsly                     2.4.2                    pypi_0    pypi
# strict-rfc3339            0.7                      pypi_0    pypi
# subprocess32              3.5.4                    pypi_0    pypi
# swagger-spec-validator    2.7.4                    pypi_0    pypi
# tensorboard               2.7.0                    pypi_0    pypi
# tensorboard-data-server   0.6.1                    pypi_0    pypi
# tensorboard-plugin-wit    1.8.0                    pypi_0    pypi
# tensorboardx              2.2                      pypi_0    pypi
# termcolor                 1.1.0                    pypi_0    pypi
# terminado                 0.12.1                   pypi_0    pypi
# testpath                  0.5.0                    pypi_0    pypi
# thinc                     8.0.13                   pypi_0    pypi
# threadpoolctl             3.0.0                    pypi_0    pypi
# tifffile                  2021.11.2                pypi_0    pypi
# tk                        8.6.10               hbc83047_0
# torchelastic              0.2.0                    pypi_0    pypi
# torchtext                 0.11.0                     py37    pytorch
# torchvision               0.11.0               py37_cu113    pytorch
# tornado                   6.1                      pypi_0    pypi
# tqdm                      4.61.2             pyhd3eb1b0_1
# traitlets                 5.1.0              pyhd3eb1b0_0
# typer                     0.4.0                    pypi_0    pypi
# typing_extensions         3.10.0.2           pyh06a4308_0
# tzdata                    2021a                h52ac0ba_0
# urllib3                   1.26.6             pyhd3eb1b0_1
# wandb                     0.12.6                   pypi_0    pypi
# wasabi                    0.8.2                    pypi_0    pypi
# wcwidth                   0.2.5              pyhd3eb1b0_0
# webcolors                 1.11.1                   pypi_0    pypi
# webencodings              0.5.1                    pypi_0    pypi
# websocket-client          1.2.1                    pypi_0    pypi
# werkzeug                  2.0.2                    pypi_0    pypi
# wheel                     0.36.2             pyhd3eb1b0_0
# widgetsnbextension        3.5.2                    pypi_0    pypi
# xz                        5.2.5                h7b6447c_0
# yaml                      0.2.5                h7b6447c_0
# yaspin                    2.1.0                    pypi_0    pypi
# zipp                      3.6.0                    pypi_0    pypi
# zlib                      1.2.11               h7b6447c_3
# zstd                      1.4.9                haebb681_0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Lets import the libraries

# %%
# Basic python and ML Libraries
import os
import random
import numpy as np
import pandas as pd
# for ignoring warnings
import warnings
warnings.filterwarnings('ignore')

# We will be reading images using OpenCV
import cv2
from PIL import Image

# xml library for parsing xml files
from xml.etree import ElementTree as et

# matplotlib for visualization
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# torchvision libraries
import torch
import torchvision
from torchvision import transforms as torchtrans  
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor

# these are the helper libraries imported.
from engine import train_one_epoch, evaluate
import utils
import transforms as T

# for image augmentations
import albumentations as A
from albumentations.pytorch.transforms import ToTensorV2

# %%
print(torch.cuda.memory_summary())
# Out:
# |===========================================================================|
# |                  PyTorch CUDA memory summary, device ID 0                 |
# |---------------------------------------------------------------------------|
# |            CUDA OOMs: 0            |        cudaMalloc retries: 0         |
# |===========================================================================|
# |        Metric         | Cur Usage  | Peak Usage | Tot Alloc  | Tot Freed  |
# |---------------------------------------------------------------------------|
# | Allocated memory      |       0 B  |       0 B  |       0 B  |       0 B  |
# |       from large pool |       0 B  |       0 B  |       0 B  |       0 B  |
# |       from small pool |       0 B  |       0 B  |       0 B  |       0 B  |
# |---------------------------------------------------------------------------|
# | Active memory         |       0 B  |       0 B  |       0 B  |       0 B  |
# |       from large pool |       0 B  |       0 B  |       0 B  |       0 B  |
# |       from small pool |       0 B  |       0 B  |       0 B  |       0 B  |
# |---------------------------------------------------------------------------|
# | GPU reserved memory   |       0 B  |       0 B  |       0 B  |       0 B  |
# |       from large pool |       0 B  |       0 B  |       0 B  |       0 B  |
# |       from small pool |       0 B  |       0 B  |       0 B  |       0 B  |
# |---------------------------------------------------------------------------|
# | Non-releasable memory |       0 B  |       0 B  |       0 B  |       0 B  |
# |       from large pool |       0 B  |       0 B  |       0 B  |       0 B  |
# |       from small pool |       0 B  |       0 B  |       0 B  |       0 B  |
# |---------------------------------------------------------------------------|
# | Allocations           |       0    |       0    |       0    |       0    |
# |       from large pool |       0    |       0    |       0    |       0    |
# |       from small pool |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Active allocs         |       0    |       0    |       0    |       0    |
# |       from large pool |       0    |       0    |       0    |       0    |
# |       from small pool |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | GPU reserved segments |       0    |       0    |       0    |       0    |
# |       from large pool |       0    |       0    |       0    |       0    |
# |       from small pool |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Non-releasable allocs |       0    |       0    |       0    |       0    |
# |       from large pool |       0    |       0    |       0    |       0    |
# |       from small pool |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Oversize allocations  |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Oversize GPU segments |       0    |       0    |       0    |       0    |
# |===========================================================================|

# %% [markdown]
# ## Dataset

# %%
# Settings:

# !pwd

files_dir = '../imgdata/6out01/trainval/'
test_dir = '../imgdata/6out01/test/'

setwidth = 500
#setheight = 7990 actual give assertionerror. 7500 works.
setheight = 7900

num_classes = 3

test_split = 0.7

num_epochs = 16

# edit these in the code below...

img_file_suffix = 'edit below'

setclasses = "edit below  self.classes = [_, 'Chip']"
# Out:
# /notebooks/ml635e2/ml635j

# %% [markdown]
# # Inspect one image..

# %%
imgs = [image for image in sorted(os.listdir(files_dir))
                    if image[-4:]=='.png']

img_name = imgs[1]
image_path = os.path.join(files_dir, img_name)

# reading the images and converting them to correct size and color    
img = cv2.imread(image_path)
imgp = Image.open(image_path)
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB).astype(np.float32)
#img_res = cv2.resize(img_rgb, (width, height), cv2.INTER_AREA)
# diving by 255
# img_res /= 255.0

print( img.shape)
print( imgp.format)
print( image_path)
# Out:
# (7990, 500, 3)
# PNG
# ../imgdata/6out01/trainval/outer_surface_210804T142702.png

# %% [markdown]
# Lets build the images dataset

# %%
# defining the files directory and testing directory
# files_dir = '../cast04c/train'
# test_dir = '../cast04c/test'
# files_dir = '../imgdata/sg/s1out/train/'
# test_dir = '../imgdata/sg/s1out/test/'


class AaImagesDataset(torch.utils.data.Dataset):

    def __init__(self, files_dir, width, height, transforms=None):
        self.transforms = transforms
        self.files_dir = files_dir
        self.height = height
        self.width = width
        
        # sorting the images for consistency
        # To get images, the extension of the filename is checked to be jpg
        self.imgs = [image for image in sorted(os.listdir(files_dir))
                        if image[-4:]=='.png']
        
        # classes: 0 index is reserved for background
        self.classes = [_, 'Chip', 'Crack']

    def __getitem__(self, idx):

        img_name = self.imgs[idx]
        image_path = os.path.join(self.files_dir, img_name)

        # reading the images and converting them to correct size and color    
        img = cv2.imread(image_path)
        imgp = Image.open(image_path)
        #print(idx, imgp.format)
        img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB).astype(np.float32)
        img_res = cv2.resize(img_rgb, (self.width, self.height), cv2.INTER_AREA)
        # diving by 255
        img_res /= 255.0
        
        # annotation file
        annot_filename = img_name[:-4] + '.xml'
        annot_file_path = os.path.join(self.files_dir, annot_filename)
        
        boxes = []
        labels = []
        tree = et.parse(annot_file_path)
        root = tree.getroot()
        
        # cv2 image gives size as height x width
        wt = img.shape[1]
        ht = img.shape[0]
        
        # box coordinates for xml files are extracted and corrected for image size given
        for member in root.findall('object'):
            labels.append(self.classes.index(member.find('name').text))
            
            # bounding box
            xmin = int(member.find('bndbox').find('xmin').text)
            xmax = int(member.find('bndbox').find('xmax').text)
            
            ymin = int(member.find('bndbox').find('ymin').text)
            ymax = int(member.find('bndbox').find('ymax').text)
            
            xmin_corr = (xmin/wt)*self.width
            xmax_corr = (xmax/wt)*self.width
            ymin_corr = (ymin/ht)*self.height
            ymax_corr = (ymax/ht)*self.height
            
            boxes.append([xmin_corr, ymin_corr, xmax_corr, ymax_corr])
        
        # convert boxes into a torch.Tensor
        boxes = torch.as_tensor(boxes, dtype=torch.float32)
        
        # getting the areas of the boxes
        area = (boxes[:, 3] - boxes[:, 1]) * (boxes[:, 2] - boxes[:, 0])

        # suppose all instances are not crowd
        iscrowd = torch.zeros((boxes.shape[0],), dtype=torch.int64)
        
        labels = torch.as_tensor(labels, dtype=torch.int64)

        target = {}
        target["boxes"] = boxes
        target["labels"] = labels
        target["area"] = area
        target["iscrowd"] = iscrowd
        # image_id
        image_id = torch.tensor([idx])
        target["image_id"] = image_id

        if self.transforms:
            sample = self.transforms(image = img_res,
                                     bboxes = target['boxes'],
                                     labels = labels)
            img_res = sample['image']
            target['boxes'] = torch.Tensor(sample['bboxes'])
                       
        return img_res, target

    def __len__(self):
        return len(self.imgs)

# %%
# check dataset
dataset = AaImagesDataset(files_dir, setwidth, setheight)
print('length of dataset = ', len(dataset), '\n')

# getting the image and target for a test index.  Feel free to change the index.
img, target = dataset[0]
print(img.shape, '\n',target)
# Out:
# length of dataset =  79
#
# (7900, 500, 3)
#  {'boxes': tensor([[ 137.0000, 2919.7371,  159.0000, 3167.9099]]), 'labels': tensor([2]), 'area': tensor([5459.8027]), 'iscrowd': tensor([0]), 'image_id': tensor([0])}

# %% [markdown]
# Points to be noted -
# 1. The dataset returns a tuple. The first element is the image shape and the second element is a dictionary.
# 2. The image is of the size, we provided while defining the dataset and the color mode is RGB.
# 3. There are four bounding boxes in the image which is evident from four lists in boxes and length of labels.

# %% [markdown]
# And its done!
#
# Dataset building is one of the hardest things in the notebook. If you got till here while understand all of the above, you are doing pretty good!
#
# Let's now see, what our data looks like. The function is inspired from [here](https://www.kaggle.com/kiwifairy/visualize-x-ray-image-with-bounding-boxes)

# %% [markdown]
# # Dataset Visualization

# %%
# Function to visualize bounding boxes in the image

def plot_img_bbox(img, target):
    # plot the image and bboxes
    # Bounding boxes are defined as follows: x-min y-min width height
    fig, a = plt.subplots(1,1)
    fig.set_size_inches(5,5)
    a.imshow(img)
    for box in ((target['boxes']).cpu()):
        print(box)
        x, y, width, height  = box[0], box[1], box[2]-box[0], box[3]-box[1]
        rect = patches.Rectangle((x, y),
                                 width, height,
                                 linewidth = 2,
                                 edgecolor = 'r',
                                 facecolor = 'none')

        # Draw the bounding box on top of the image
        a.add_patch(rect)
    plt.show()
    
# plotting the image with bboxes. Feel free to change the index
img, target = dataset[1]
plot_img_bbox(img, target)
print("img:",img,"targ:",target)
# Out:
# tensor([ 307.0000, 6735.2690,  332.0000, 6897.4219])
# img: [[[0.01176471 0.01176471 0.01176471]
#   [0.01178704 0.01178704 0.01178704]
#   [0.01178704 0.01178704 0.01178704]
#   ...
#   [0.01176471 0.01176471 0.01176471]
#   [0.01176471 0.01176471 0.01176471]
#   [0.01176471 0.01176471 0.01176471]]
#
#  [[0.01176471 0.01176471 0.01176471]
#   [0.01561926 0.01561926 0.01561926]
#   [0.01568628 0.01568628 0.01568628]
#   ...
#   [0.01176471 0.01176471 0.01176471]
#   [0.01176471 0.01176471 0.01176471]
#   [0.01176471 0.01176471 0.01176471]]
#
#  [[0.01176471 0.01176471 0.01176471]
#   [0.0118764  0.0118764  0.0118764 ]
#   [0.01557458 0.01557458 0.01557458]
#   ...
#   [0.01176471 0.01176471 0.01176471]
#   [0.01176471 0.01176471 0.01176471]
#   [0.01176471 0.01176471 0.01176471]]
#
#  ...
#
#  [[0.01176471 0.01176471 0.01176471]
#   [0.01176471 0.01176471 0.01176471]
#   [0.01176471 0.01176471 0.01176471]
#   ...
#   [0.01176471 0.01176471 0.01176471]
#   [0.01176471 0.01176471 0.01176471]
#   [0.01176471 0.01176471 0.01176471]]
#
#  [[0.01176471 0.01176471 0.01176471]
#   [0.01176471 0.01176471 0.01176471]
#   [0.01176471 0.01176471 0.01176471]
#   ...
#   [0.01176471 0.01176471 0.01176471]
#   [0.01176471 0.01176471 0.01176471]
#   [0.01176471 0.01176471 0.01176471]]
#
#  [[0.01176471 0.01176471 0.01176471]
#   [0.01176471 0.01176471 0.01176471]
#   [0.01176471 0.01176471 0.01176471]
#   ...
#   [0.01176471 0.01176471 0.01176471]
#   [0.01176471 0.01176471 0.01176471]
#   [0.01176471 0.01176471 0.01176471]]] targ: {'boxes': tensor([[ 307.0000, 6735.2690,  332.0000, 6897.4219]]), 'labels': tensor([2]), 'area': tensor([4053.8208]), 'iscrowd': tensor([0]), 'image_id': tensor([1])}

# %% [markdown]
# You can see that we are doing great till now, as the bbox is correctly placed.
#
# Lets build the model then!

# %% [markdown]
# # Prep Model

# %% [markdown]
# We will define a function for loading the model. We will call it later

# %%
def get_object_detection_model(num_classes):

    # load a model pre-trained pre-trained on COCO
    model = torchvision.models.detection.fasterrcnn_resnet50_fpn(pretrained=True)
    
    # get number of input features for the classifier
    in_features = model.roi_heads.box_predictor.cls_score.in_features
    # replace the pre-trained head with a new one
    model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes) 

    return model

# %% [markdown]
# You can clearly see, how easy it is to load and prepare the model using pytorch

# %% [markdown]
# # Dataset Augmentations

# %% [markdown]
# This is where we can apply augmentations to the image.
#
# The augmentations to object detection vary from normal augmentations becuase here we need to ensure that, bbox still aligns with the object correctly after transforming.
#
# Here I have added random flip transform, feel free to customize it as you feel

# %%
# Send train=True fro training transforms and False for val/test transforms
def get_transform(train):
    
    if train:
        return A.Compose([
                            A.HorizontalFlip(0.5),
                     # ToTensorV2 converts image to pytorch tensor without div by 255
                            ToTensorV2(p=1.0) 
                        ], bbox_params={'format': 'pascal_voc', 'label_fields': ['labels']})
    else:
        return A.Compose([
                            ToTensorV2(p=1.0)
                        ], bbox_params={'format': 'pascal_voc', 'label_fields': ['labels']})

# %% [markdown]
# # Preparing dataset

# %% [markdown]
# Now lets prepare datasets and dataloaders for training and testing.

# %%
# use our dataset and defined transformations
dataset = AaImagesDataset(files_dir,  setwidth, setheight, transforms= get_transform(train=True))
dataset_test = AaImagesDataset(files_dir, setwidth, setheight, transforms= get_transform(train=False))

# split the dataset in train and test set
torch.manual_seed(1)
indices = torch.randperm(len(dataset)).tolist()

# train test split
# test_split = 0.5
tsize = int(len(dataset)*test_split)
dataset = torch.utils.data.Subset(dataset, indices[:-tsize])
dataset_test = torch.utils.data.Subset(dataset_test, indices[-tsize:])

# define training and validation data loaders
data_loader = torch.utils.data.DataLoader(
    dataset, batch_size=10, shuffle=True, num_workers=4,
    collate_fn=utils.collate_fn)

data_loader_test = torch.utils.data.DataLoader(
    dataset_test, batch_size=10, shuffle=False, num_workers=4,
    collate_fn=utils.collate_fn)

# %% [markdown]
# # Training

# %% [markdown]
# Let's prepare the model for training

# %%
# to train on gpu if selected.
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
print(device)

# num_classes = 2

# get the model using our helper function
model = get_object_detection_model(num_classes)

# move model to the right device
model.to(device)

# construct an optimizer
params = [p for p in model.parameters() if p.requires_grad]
optimizer = torch.optim.SGD(params, lr=0.005,
                            momentum=0.9, weight_decay=0.0005)

# and a learning rate scheduler which decreases the learning rate by
# 10x every 3 epochs
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer,
                                               step_size=3,
                                               gamma=0.1)
# Out:
# cuda

# %% [markdown]
# Let the training begin!

# %%
# !export PYTORCH_CUDA_ALLOC_CONF=max_split_size_mb:128

# %% [markdown]
# # Run the training.......

# %%
# training for 10 epochs

# edit me..
#num_epochs = 3

# !export PYTORCH_CUDA_ALLOC_CONF=max_split_size_mb:128
torch.cuda.empty_cache()
    
for epoch in range(num_epochs):
    # training for one epoch
    train_one_epoch(model, optimizer, data_loader, device, epoch, print_freq=10)
    # update the learning rate
    lr_scheduler.step()
    # evaluate on the test dataset
    evaluate(model, data_loader_test, device=device)
    
print('reached.end.')
# Out:
# Epoch: [0]  [0/3]  eta: 0:00:33  lr: 0.002502  loss: 2.1728 (2.1728)  loss_classifier: 1.0409 (1.0409)  loss_box_reg: 0.0049 (0.0049)  loss_objectness: 0.9057 (0.9057)  loss_rpn_box_reg: 0.2213 (0.2213)  time: 11.0052  data: 9.7503  max mem: 2563
# Epoch: [0]  [2/3]  eta: 0:00:04  lr: 0.005000  loss: 1.3200 (1.2413)  loss_classifier: 1.0374 (0.7435)  loss_box_reg: 0.0097 (0.0105)  loss_objectness: 0.2412 (0.4017)  loss_rpn_box_reg: 0.0316 (0.0856)  time: 4.1125  data: 3.3337  max mem: 2563
# Epoch: [0] Total time: 0:00:12 (4.1464 s / it)
# creating index...
# index created!
# Test:  [0/6]  eta: 0:00:57  model_time: 0.3396 (0.3396)  evaluator_time: 0.0079 (0.0079)  time: 9.5526  data: 9.0377  max mem: 2563
# Test:  [5/6]  eta: 0:00:02  model_time: 0.3376 (0.3089)  evaluator_time: 0.0079 (0.0081)  time: 2.4454  data: 1.9868  max mem: 2563
# Test: Total time: 0:00:14 (2.4636 s / it)
# Averaged stats: model_time: 0.3376 (0.3089)  evaluator_time: 0.0079 (0.0081)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# Epoch: [1]  [0/3]  eta: 0:00:29  lr: 0.005000  loss: 0.4233 (0.4233)  loss_classifier: 0.0241 (0.0241)  loss_box_reg: 0.0077 (0.0077)  loss_objectness: 0.1979 (0.1979)  loss_rpn_box_reg: 0.1936 (0.1936)  time: 9.8792  data: 9.1158  max mem: 2563
# Epoch: [1]  [2/3]  eta: 0:00:03  lr: 0.005000  loss: 0.4233 (0.3788)  loss_classifier: 0.0518 (0.0522)  loss_box_reg: 0.0203 (0.0161)  loss_objectness: 0.1979 (0.2308)  loss_rpn_box_reg: 0.0328 (0.0796)  time: 3.7153  data: 3.1117  max mem: 2563
# Epoch: [1] Total time: 0:00:11 (3.7517 s / it)
# creating index...
# index created!
# Test:  [0/6]  eta: 0:01:03  model_time: 0.3252 (0.3252)  evaluator_time: 0.0055 (0.0055)  time: 10.5964  data: 10.0410  max mem: 2563
# Test:  [5/6]  eta: 0:00:02  model_time: 0.3244 (0.3101)  evaluator_time: 0.0039 (0.0049)  time: 2.5857  data: 2.1311  max mem: 2563
# Test: Total time: 0:00:15 (2.6065 s / it)
# Averaged stats: model_time: 0.3244 (0.3101)  evaluator_time: 0.0039 (0.0049)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# Epoch: [2]  [0/3]  eta: 0:00:33  lr: 0.005000  loss: 0.3392 (0.3392)  loss_classifier: 0.1533 (0.1533)  loss_box_reg: 0.0338 (0.0338)  loss_objectness: 0.1297 (0.1297)  loss_rpn_box_reg: 0.0224 (0.0224)  time: 11.0414  data: 10.2989  max mem: 2563
# Epoch: [2]  [2/3]  eta: 0:00:04  lr: 0.005000  loss: 0.3392 (0.4624)  loss_classifier: 0.1456 (0.1407)  loss_box_reg: 0.0283 (0.0270)  loss_objectness: 0.1297 (0.2316)  loss_rpn_box_reg: 0.0224 (0.0631)  time: 4.1038  data: 3.4998  max mem: 2563
# Epoch: [2] Total time: 0:00:12 (4.1412 s / it)
# creating index...
# index created!
# Test:  [0/6]  eta: 0:00:53  model_time: 0.3560 (0.3560)  evaluator_time: 0.0102 (0.0102)  time: 8.9974  data: 8.5016  max mem: 2563
# Test:  [5/6]  eta: 0:00:02  model_time: 0.3224 (0.3092)  evaluator_time: 0.0038 (0.0057)  time: 2.6790  data: 2.2135  max mem: 2563
# Test: Total time: 0:00:16 (2.6979 s / it)
# Averaged stats: model_time: 0.3224 (0.3092)  evaluator_time: 0.0038 (0.0057)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# Epoch: [3]  [0/3]  eta: 0:00:29  lr: 0.000500  loss: 0.2288 (0.2288)  loss_classifier: 0.1202 (0.1202)  loss_box_reg: 0.0241 (0.0241)  loss_objectness: 0.0512 (0.0512)  loss_rpn_box_reg: 0.0335 (0.0335)  time: 9.8750  data: 9.1311  max mem: 2563
# Epoch: [3]  [2/3]  eta: 0:00:03  lr: 0.000500  loss: 0.3059 (0.3075)  loss_classifier: 0.1202 (0.1443)  loss_box_reg: 0.0241 (0.0302)  loss_objectness: 0.0512 (0.0712)  loss_rpn_box_reg: 0.0335 (0.0619)  time: 3.7242  data: 3.1243  max mem: 2563
# Epoch: [3] Total time: 0:00:11 (3.7675 s / it)
# creating index...
# index created!
# Test:  [0/6]  eta: 0:01:07  model_time: 0.3728 (0.3728)  evaluator_time: 0.0061 (0.0061)  time: 11.2010  data: 10.6921  max mem: 2563
# Test:  [5/6]  eta: 0:00:02  model_time: 0.3197 (0.3063)  evaluator_time: 0.0031 (0.0037)  time: 2.6321  data: 2.1945  max mem: 2563
# Test: Total time: 0:00:15 (2.6469 s / it)
# Averaged stats: model_time: 0.3197 (0.3063)  evaluator_time: 0.0031 (0.0037)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# Epoch: [4]  [0/3]  eta: 0:00:31  lr: 0.000500  loss: 0.3765 (0.3765)  loss_classifier: 0.1313 (0.1313)  loss_box_reg: 0.0214 (0.0214)  loss_objectness: 0.0987 (0.0987)  loss_rpn_box_reg: 0.1250 (0.1250)  time: 10.6261  data: 9.8821  max mem: 2563
# Epoch: [4]  [2/3]  eta: 0:00:03  lr: 0.000500  loss: 0.2595 (0.2963)  loss_classifier: 0.1227 (0.1219)  loss_box_reg: 0.0311 (0.0292)  loss_objectness: 0.0706 (0.0766)  loss_rpn_box_reg: 0.0413 (0.0686)  time: 3.9794  data: 3.3669  max mem: 2563
# Epoch: [4] Total time: 0:00:12 (4.0185 s / it)
# creating index...
# index created!
# Test:  [0/6]  eta: 0:01:01  model_time: 0.4171 (0.4171)  evaluator_time: 0.0145 (0.0145)  time: 10.1958  data: 9.5373  max mem: 2563
# Test:  [5/6]  eta: 0:00:02  model_time: 0.3403 (0.3267)  evaluator_time: 0.0044 (0.0064)  time: 2.6912  data: 2.1922  max mem: 2563
# Test: Total time: 0:00:16 (2.7081 s / it)
# Averaged stats: model_time: 0.3403 (0.3267)  evaluator_time: 0.0044 (0.0064)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# Epoch: [5]  [0/3]  eta: 0:00:35  lr: 0.000500  loss: 0.2238 (0.2238)  loss_classifier: 0.1072 (0.1072)  loss_box_reg: 0.0242 (0.0242)  loss_objectness: 0.0664 (0.0664)  loss_rpn_box_reg: 0.0260 (0.0260)  time: 11.9144  data: 10.8105  max mem: 2563
# Epoch: [5]  [2/3]  eta: 0:00:04  lr: 0.000500  loss: 0.2484 (0.2815)  loss_classifier: 0.1072 (0.1177)  loss_box_reg: 0.0267 (0.0292)  loss_objectness: 0.0664 (0.0719)  loss_rpn_box_reg: 0.0260 (0.0627)  time: 4.6087  data: 3.8883  max mem: 2563
# Epoch: [5] Total time: 0:00:13 (4.6454 s / it)
# creating index...
# index created!
# Test:  [0/6]  eta: 0:01:06  model_time: 0.3924 (0.3924)  evaluator_time: 0.0077 (0.0077)  time: 11.0942  data: 10.5274  max mem: 2563
# Test:  [5/6]  eta: 0:00:02  model_time: 0.3158 (0.3196)  evaluator_time: 0.0037 (0.0046)  time: 2.7643  data: 2.3081  max mem: 2563
# Test: Total time: 0:00:16 (2.7856 s / it)
# Averaged stats: model_time: 0.3158 (0.3196)  evaluator_time: 0.0037 (0.0046)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# Epoch: [6]  [0/3]  eta: 0:00:37  lr: 0.000050  loss: 0.3563 (0.3563)  loss_classifier: 0.0951 (0.0951)  loss_box_reg: 0.0212 (0.0212)  loss_objectness: 0.0983 (0.0983)  loss_rpn_box_reg: 0.1417 (0.1417)  time: 12.6045  data: 11.8371  max mem: 2563
# Epoch: [6]  [2/3]  eta: 0:00:04  lr: 0.000050  loss: 0.2308 (0.2651)  loss_classifier: 0.1023 (0.1133)  loss_box_reg: 0.0248 (0.0309)  loss_objectness: 0.0505 (0.0621)  loss_rpn_box_reg: 0.0306 (0.0587)  time: 4.6172  data: 4.0054  max mem: 2563
# Epoch: [6] Total time: 0:00:13 (4.6519 s / it)
# creating index...
# index created!
# Test:  [0/6]  eta: 0:01:02  model_time: 0.3776 (0.3776)  evaluator_time: 0.0052 (0.0052)  time: 10.3872  data: 9.8521  max mem: 2563
# Test:  [5/6]  eta: 0:00:02  model_time: 0.3416 (0.3257)  evaluator_time: 0.0036 (0.0043)  time: 2.6115  data: 2.1424  max mem: 2563
# Test: Total time: 0:00:15 (2.6296 s / it)
# Averaged stats: model_time: 0.3416 (0.3257)  evaluator_time: 0.0036 (0.0043)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# Epoch: [7]  [0/3]  eta: 0:00:34  lr: 0.000050  loss: 0.3558 (0.3558)  loss_classifier: 0.0897 (0.0897)  loss_box_reg: 0.0212 (0.0212)  loss_objectness: 0.1014 (0.1014)  loss_rpn_box_reg: 0.1435 (0.1435)  time: 11.6263  data: 10.8419  max mem: 2563
# Epoch: [7]  [2/3]  eta: 0:00:04  lr: 0.000050  loss: 0.2139 (0.2582)  loss_classifier: 0.1112 (0.1049)  loss_box_reg: 0.0212 (0.0253)  loss_objectness: 0.0470 (0.0646)  loss_rpn_box_reg: 0.0250 (0.0634)  time: 4.2955  data: 3.6803  max mem: 2563
# Epoch: [7] Total time: 0:00:12 (4.3309 s / it)
# creating index...
# index created!
# Test:  [0/6]  eta: 0:00:59  model_time: 0.3420 (0.3420)  evaluator_time: 0.0050 (0.0050)  time: 9.9885  data: 9.4995  max mem: 2563
# Test:  [5/6]  eta: 0:00:02  model_time: 0.3377 (0.3063)  evaluator_time: 0.0041 (0.0049)  time: 2.7008  data: 2.2428  max mem: 2563
# Test: Total time: 0:00:16 (2.7189 s / it)
# Averaged stats: model_time: 0.3377 (0.3063)  evaluator_time: 0.0041 (0.0049)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# Epoch: [8]  [0/3]  eta: 0:00:32  lr: 0.000050  loss: 0.1951 (0.1951)  loss_classifier: 0.1072 (0.1072)  loss_box_reg: 0.0294 (0.0294)  loss_objectness: 0.0420 (0.0420)  loss_rpn_box_reg: 0.0164 (0.0164)  time: 10.9915  data: 10.2084  max mem: 2563
# Epoch: [8]  [2/3]  eta: 0:00:04  lr: 0.000050  loss: 0.2243 (0.2608)  loss_classifier: 0.1038 (0.1025)  loss_box_reg: 0.0294 (0.0281)  loss_objectness: 0.0581 (0.0668)  loss_rpn_box_reg: 0.0288 (0.0634)  time: 4.1049  data: 3.4877  max mem: 2563
# Epoch: [8] Total time: 0:00:12 (4.1480 s / it)
# creating index...
# index created!
# Test:  [0/6]  eta: 0:01:01  model_time: 0.3380 (0.3380)  evaluator_time: 0.0039 (0.0039)  time: 10.2814  data: 9.7570  max mem: 2563
# Test:  [5/6]  eta: 0:00:02  model_time: 0.3380 (0.3175)  evaluator_time: 0.0029 (0.0039)  time: 2.6548  data: 2.1804  max mem: 2563
# Test: Total time: 0:00:16 (2.6726 s / it)
# Averaged stats: model_time: 0.3380 (0.3175)  evaluator_time: 0.0029 (0.0039)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# Epoch: [9]  [0/3]  eta: 0:00:31  lr: 0.000005  loss: 0.3513 (0.3513)  loss_classifier: 0.0949 (0.0949)  loss_box_reg: 0.0262 (0.0262)  loss_objectness: 0.0926 (0.0926)  loss_rpn_box_reg: 0.1376 (0.1376)  time: 10.4902  data: 9.7429  max mem: 2563
# Epoch: [9]  [2/3]  eta: 0:00:03  lr: 0.000005  loss: 0.2233 (0.2562)  loss_classifier: 0.0949 (0.0972)  loss_box_reg: 0.0262 (0.0271)  loss_objectness: 0.0576 (0.0669)  loss_rpn_box_reg: 0.0330 (0.0651)  time: 3.9255  data: 3.3082  max mem: 2563
# Epoch: [9] Total time: 0:00:11 (3.9674 s / it)
# creating index...
# index created!
# Test:  [0/6]  eta: 0:01:02  model_time: 0.3386 (0.3386)  evaluator_time: 0.0121 (0.0121)  time: 10.4222  data: 9.8863  max mem: 2563
# Test:  [5/6]  eta: 0:00:02  model_time: 0.3341 (0.3081)  evaluator_time: 0.0050 (0.0069)  time: 2.7330  data: 2.2503  max mem: 2563
# Test: Total time: 0:00:16 (2.7523 s / it)
# Averaged stats: model_time: 0.3341 (0.3081)  evaluator_time: 0.0050 (0.0069)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# Epoch: [10]  [0/3]  eta: 0:00:33  lr: 0.000005  loss: 0.3611 (0.3611)  loss_classifier: 0.0911 (0.0911)  loss_box_reg: 0.0206 (0.0206)  loss_objectness: 0.0984 (0.0984)  loss_rpn_box_reg: 0.1511 (0.1511)  time: 11.0796  data: 10.2307  max mem: 2563
# Epoch: [10]  [2/3]  eta: 0:00:04  lr: 0.000005  loss: 0.2184 (0.2588)  loss_classifier: 0.0993 (0.1006)  loss_box_reg: 0.0275 (0.0293)  loss_objectness: 0.0530 (0.0662)  loss_rpn_box_reg: 0.0263 (0.0628)  time: 4.2260  data: 3.5763  max mem: 2563
# Epoch: [10] Total time: 0:00:12 (4.2672 s / it)
# creating index...
# index created!
# Test:  [0/6]  eta: 0:01:06  model_time: 0.3561 (0.3561)  evaluator_time: 0.0186 (0.0186)  time: 11.0968  data: 10.5787  max mem: 2563
# Test:  [5/6]  eta: 0:00:02  model_time: 0.3240 (0.3089)  evaluator_time: 0.0030 (0.0067)  time: 2.7585  data: 2.3055  max mem: 2563
# Test: Total time: 0:00:16 (2.7801 s / it)
# Averaged stats: model_time: 0.3240 (0.3089)  evaluator_time: 0.0030 (0.0067)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# Epoch: [11]  [0/3]  eta: 0:00:32  lr: 0.000005  loss: 0.3640 (0.3640)  loss_classifier: 0.1040 (0.1040)  loss_box_reg: 0.0309 (0.0309)  loss_objectness: 0.0951 (0.0951)  loss_rpn_box_reg: 0.1339 (0.1339)  time: 10.6869  data: 9.9119  max mem: 2563
# Epoch: [11]  [2/3]  eta: 0:00:04  lr: 0.000005  loss: 0.1999 (0.2543)  loss_classifier: 0.1040 (0.1057)  loss_box_reg: 0.0309 (0.0289)  loss_objectness: 0.0563 (0.0608)  loss_rpn_box_reg: 0.0371 (0.0588)  time: 4.0012  data: 3.3708  max mem: 2563
# Epoch: [11] Total time: 0:00:12 (4.0424 s / it)
# creating index...
# index created!
# Test:  [0/6]  eta: 0:00:53  model_time: 0.3602 (0.3602)  evaluator_time: 0.0127 (0.0127)  time: 8.9035  data: 8.3351  max mem: 2563
# Test:  [5/6]  eta: 0:00:02  model_time: 0.3602 (0.3313)  evaluator_time: 0.0059 (0.0079)  time: 2.6648  data: 2.1706  max mem: 2563
# Test: Total time: 0:00:16 (2.6827 s / it)
# Averaged stats: model_time: 0.3602 (0.3313)  evaluator_time: 0.0059 (0.0079)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# Epoch: [12]  [0/3]  eta: 0:00:31  lr: 0.000001  loss: 0.3339 (0.3339)  loss_classifier: 0.0759 (0.0759)  loss_box_reg: 0.0166 (0.0166)  loss_objectness: 0.0931 (0.0931)  loss_rpn_box_reg: 0.1483 (0.1483)  time: 10.5242  data: 9.5845  max mem: 2563
# Epoch: [12]  [2/3]  eta: 0:00:04  lr: 0.000001  loss: 0.2259 (0.2574)  loss_classifier: 0.1013 (0.1008)  loss_box_reg: 0.0307 (0.0274)  loss_objectness: 0.0540 (0.0654)  loss_rpn_box_reg: 0.0265 (0.0638)  time: 4.1687  data: 3.4952  max mem: 2563
# Epoch: [12] Total time: 0:00:12 (4.2131 s / it)
# creating index...
# index created!
# Test:  [0/6]  eta: 0:00:58  model_time: 0.3969 (0.3969)  evaluator_time: 0.0121 (0.0121)  time: 9.7270  data: 9.1126  max mem: 2563
# Test:  [5/6]  eta: 0:00:02  model_time: 0.3240 (0.3172)  evaluator_time: 0.0052 (0.0062)  time: 2.5575  data: 2.0856  max mem: 2563
# Test: Total time: 0:00:15 (2.5738 s / it)
# Averaged stats: model_time: 0.3240 (0.3172)  evaluator_time: 0.0052 (0.0062)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# Epoch: [13]  [0/3]  eta: 0:00:33  lr: 0.000001  loss: 0.1943 (0.1943)  loss_classifier: 0.0809 (0.0809)  loss_box_reg: 0.0219 (0.0219)  loss_objectness: 0.0581 (0.0581)  loss_rpn_box_reg: 0.0334 (0.0334)  time: 11.3247  data: 10.5652  max mem: 2563
# Epoch: [13]  [2/3]  eta: 0:00:04  lr: 0.000001  loss: 0.1943 (0.3425)  loss_classifier: 0.0991 (0.1114)  loss_box_reg: 0.0250 (0.0298)  loss_objectness: 0.0581 (0.0847)  loss_rpn_box_reg: 0.0334 (0.1166)  time: 4.1903  data: 3.5816  max mem: 2563
# Epoch: [13] Total time: 0:00:12 (4.2309 s / it)
# creating index...
# index created!
# Test:  [0/6]  eta: 0:01:05  model_time: 0.3678 (0.3678)  evaluator_time: 0.0087 (0.0087)  time: 10.8462  data: 10.2734  max mem: 2563
# Test:  [5/6]  eta: 0:00:02  model_time: 0.3191 (0.3089)  evaluator_time: 0.0047 (0.0059)  time: 2.6775  data: 2.2165  max mem: 2563
# Test: Total time: 0:00:16 (2.6932 s / it)
# Averaged stats: model_time: 0.3191 (0.3089)  evaluator_time: 0.0047 (0.0059)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# Epoch: [14]  [0/3]  eta: 0:00:36  lr: 0.000001  loss: 0.3205 (0.3205)  loss_classifier: 0.0840 (0.0840)  loss_box_reg: 0.0210 (0.0210)  loss_objectness: 0.0825 (0.0825)  loss_rpn_box_reg: 0.1329 (0.1329)  time: 12.2138  data: 11.4662  max mem: 2563
# Epoch: [14]  [2/3]  eta: 0:00:04  lr: 0.000001  loss: 0.2452 (0.2640)  loss_classifier: 0.1040 (0.1013)  loss_box_reg: 0.0306 (0.0274)  loss_objectness: 0.0745 (0.0693)  loss_rpn_box_reg: 0.0360 (0.0659)  time: 4.4883  data: 3.8854  max mem: 2563
# Epoch: [14] Total time: 0:00:13 (4.5375 s / it)
# creating index...
# index created!
# Test:  [0/6]  eta: 0:01:10  model_time: 0.3784 (0.3784)  evaluator_time: 0.0069 (0.0069)  time: 11.6853  data: 11.1588  max mem: 2563
# Test:  [5/6]  eta: 0:00:02  model_time: 0.3310 (0.3250)  evaluator_time: 0.0034 (0.0050)  time: 2.9259  data: 2.4297  max mem: 2563
# Test: Total time: 0:00:17 (2.9429 s / it)
# Averaged stats: model_time: 0.3310 (0.3250)  evaluator_time: 0.0034 (0.0050)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# Epoch: [15]  [0/3]  eta: 0:00:34  lr: 0.000000  loss: 0.1916 (0.1916)  loss_classifier: 0.0809 (0.0809)  loss_box_reg: 0.0208 (0.0208)  loss_objectness: 0.0585 (0.0585)  loss_rpn_box_reg: 0.0314 (0.0314)  time: 11.4667  data: 10.6783  max mem: 2563
# Epoch: [15]  [2/3]  eta: 0:00:04  lr: 0.000000  loss: 0.2436 (0.2621)  loss_classifier: 0.0983 (0.1117)  loss_box_reg: 0.0249 (0.0304)  loss_objectness: 0.0585 (0.0611)  loss_rpn_box_reg: 0.0314 (0.0589)  time: 4.4880  data: 3.8605  max mem: 2563
# Epoch: [15] Total time: 0:00:13 (4.5268 s / it)
# creating index...
# index created!
# Test:  [0/6]  eta: 0:01:12  model_time: 0.3993 (0.3993)  evaluator_time: 0.0140 (0.0140)  time: 12.0160  data: 11.3872  max mem: 2563
# Test:  [5/6]  eta: 0:00:02  model_time: 0.3153 (0.3130)  evaluator_time: 0.0034 (0.0051)  time: 2.8272  data: 2.3775  max mem: 2563
# Test: Total time: 0:00:17 (2.8480 s / it)
# Averaged stats: model_time: 0.3153 (0.3130)  evaluator_time: 0.0034 (0.0051)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# reached.end.

# %% [markdown]
# # Comments
#
# An AP of 0.78-0.80 is not bad but perhaps we can make it even better with more augmentations, I will leave that to you.

# %% [markdown]
# # Decode predictions

# %% [markdown]
# Our model predicts a lot of bounding boxes per image, to take out the overlapping ones, We will use **Non Max Suppression** if you want to brush up on that, check [this](https://towardsdatascience.com/non-maximum-suppression-nms-93ce178e177c) out.
#
# Torchvision provides us a utility to apply nms to our predictions, lets build a function `apply_nms` using that.

# %%
# the function takes the original prediction and the iou threshold.

def apply_nms(orig_prediction, iou_thresh=0.3):
    
    # torchvision returns the indices of the bboxes to keep
    keep = torchvision.ops.nms(orig_prediction['boxes'], orig_prediction['scores'], iou_thresh)
    
    final_prediction = orig_prediction
    final_prediction['boxes'] = final_prediction['boxes'][keep]
    final_prediction['scores'] = final_prediction['scores'][keep]
    final_prediction['labels'] = final_prediction['labels'][keep]
    
    return final_prediction

# function to convert a torchtensor back to PIL image
def torch_to_pil(img):
    return torchtrans.ToPILImage()(img).convert('RGB')

# %% [markdown]
# # Testing our Generated/trained Model

# %% [markdown]
# Lets take an image from our test dataset and see, how our model does.
#
# We will first see, how many bounding boxes does our model predict compared to actual

# %%
# pick one image from the test set
img, target = dataset_test[6]
# put the model in evaluation mode
model.eval()
with torch.no_grad():
    prediction = model([img.to(device)])[0]
    
print('predicted #boxes: ', len(prediction['labels']))
print('real #boxes: ', len(target['labels']))
# Out:
# predicted #boxes:  0
# real #boxes:  1

# %% [markdown]
# Whoa! Thats a lot of bboxes. Lets plot them and check what did it predict

# %%
print('EXPECTED OUTPUT')
plot_img_bbox(torch_to_pil(img), target)
# Out:
# EXPECTED OUTPUT
# tensor([ 299.0000, 7030.9014,  345.0000, 7556.9087])

# %%
print('MODEL OUTPUT')
plot_img_bbox(torch_to_pil(img), prediction)
# Out:
# MODEL OUTPUT

# %% [markdown]
# You can see that our model predicts a lot of bounding boxes for every apple. Lets apply nms to it and see the final output

# %%
nms_prediction = apply_nms(prediction, iou_thresh=0.8)
print('NMS APPLIED MODEL OUTPUT')
plot_img_bbox(torch_to_pil(img), nms_prediction)
# Out:
# NMS APPLIED MODEL OUTPUT

# %% [markdown]
# Now lets take an image from the test set and try to predict on it

# %%
## !pwd
test_dataset = AaImagesDataset(test_dir,  setwidth, setheight, transforms= get_transform(train=True))
# pick one image from the test set
img, target = test_dataset[1]
# put the model in evaluation mode
model.eval()
with torch.no_grad():
    prediction = model([img.to(device)])[0]
    
print('EXPECTED OUTPUT\n')
plot_img_bbox(torch_to_pil(img), target)
print('MODEL OUTPUT\n')
nms_prediction = apply_nms(prediction, iou_thresh=0.1)

plot_img_bbox(torch_to_pil(img), nms_prediction)
# Out:
# EXPECTED OUTPUT
#
# tensor([ 110.0000, 3895.6196,  193.0000, 4167.5220])
# MODEL OUTPUT

# %% [markdown]
# The model did predict a void even though it was a small amount of image data and a simple short training.
#
# But fear not, this is just a base line model here are some ideas we can improve it -
# 1. Use a better model.
#    We have the option of changing the backbone of our model which at present is `resnet 50` and the fine tune it.
# 2. We can change the training configurations like size of the images, optimizers and learning rate schedule.
# 3. We can add more augmentations.
#    We have used the Albumentations library which has an extensive library of data augmentation functions. Feel free to explore and try them out.

# %% [markdown]
# # Fin.
#
# That's it for the notebook.
